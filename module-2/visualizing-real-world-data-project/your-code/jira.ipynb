# %% [markdown]
# # Analyze some jira tickets from Mango database

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('jira_tickets.csv')
data.head()
# Out:
#   Issue Type    Issue key  Issue id  \
# 0       Task  MGPSUP-2511     56717
# 1       Task  MGPSUP-2406     55484
# 2       Task  MGPSUP-2387     55500
# 3       Task  MGPSUP-2264     54625
# 4       Task  MGPSUP-2022     51208
#
#                                              Summary      Assignee  \
# 0  Régularisation des account default en négatif ...  mickael.pois
# 1  Régularisation des account default en négatif ...           NaN
# 2  Extract successful Payin Bankwire data for wal...           NaN
# 3                           Report desynch - KOALECT  mickael.pois
# 4    "Submitting" Mandate status shown to the client           NaN
#
#           Reporter Priority    Status Resolution           Created  \
# 0  nicolas.gicquel      NaN      Done      Fixed  2019-05-17 11:56
# 1  nicolas.gicquel      NaN      Done      Fixed  2019-02-13 09:54
# 2        removed21      NaN  Won't Do        NaN  2019-02-13 15:19
# 3   maxence.busson      NaN      Done       Done  2018-12-07 11:41
# ...

# %%
data.columns
# Out:
# Index(['Summary', 'Issue key', 'Issue id', 'Issue Type', 'Status',
#        'Project key', 'Project name', 'Project type', 'Project lead',
#        'Project description',
#        ...
#        'Comment.35', 'Comment.36', 'Comment.37', 'Comment.38', 'Comment.39',
#        'Comment.40', 'Comment.41', 'Comment.42', 'Comment.43', 'Comment.44'],
#       dtype='object', length=530)

# %%
data["Labels.1"].fillna("No Label", inplace = True) 
data["Labels.2"].fillna("No Label", inplace = True) 
data["Labels.3"].fillna("No Label", inplace = True)

# %%
data["Labels"] = data["Labels.1"].map(str) + ',' + data["Labels.2"].map(str) + ',' + data["Labels.3"].map(str)
data.head()
# Out:
#   Issue Type    Issue key  Issue id  \
# 0       Task  MGPSUP-2511     56717
# 1       Task  MGPSUP-2406     55484
# 2       Task  MGPSUP-2387     55500
# 3       Task  MGPSUP-2264     54625
# 4       Task  MGPSUP-2022     51208
#
#                                              Summary      Assignee  \
# 0  Régularisation des account default en négatif ...  mickael.pois
# 1  Régularisation des account default en négatif ...           NaN
# 2  Extract successful Payin Bankwire data for wal...           NaN
# 3                           Report desynch - KOALECT  mickael.pois
# 4    "Submitting" Mandate status shown to the client           NaN
#
#           Reporter Priority    Status Resolution           Created  \
# 0  nicolas.gicquel      NaN      Done      Fixed  2019-05-17 11:56
# 1  nicolas.gicquel      NaN      Done      Fixed  2019-02-13 09:54
# 2        removed21      NaN  Won't Do        NaN  2019-02-13 15:19
# 3   maxence.busson      NaN      Done       Done  2018-12-07 11:41
# ...
