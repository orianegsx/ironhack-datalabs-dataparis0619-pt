# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %%
plt.plot(x, y, linewidth=20.0, grid)

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
#plt.plot(x, y, x, z)
#plt.show()

#OR

plt.plot(x, y, 'b',linewidth=2.0)  
plt.plot(x, z, 'r',linewidth=2.0) 
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y)
plt.subplot(1,2,2)
plt.plot(x,z)

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)

x = np.arange(0,100)
y = x*2
z = x**2

fig, [ax1, ax2] = plt.subplots(1,2, figsize=(15,2))
ax1.plot(x,y, color='r')
ax1.set_title('X * 2 PLOT')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')   

ax2.plot(x,z, color='b')
ax2.set_title('X^2 PLOT')
ax2.set_xlabel('x label')
ax2.set_ylabel('y label')



plt.show()

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
from matplotlib.pyplot import figure

fig, ax = plt.subplots(figsize=(20,8))
ax.plot(x, y)

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
fig, ax = plt.subplots(figsize=(20,8))
ax.set_xlabel('x label')     
ax.set_ylabel('y label') 
ax.plot(x, y)

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
from math import *

# %%
x = np.arange(0, 100)
y = x**2 #np.exp(x) + 100
z = np.exp(x)


plt.figure()
plt.plot(x, y)
plt.plot(x, z)
plt.xscale("linear")
plt.yscale("log")

plt.xlabel('$x$')
plt.ylabel('y and z')


plt.show()

#Comment utiliser set_xscale ????

# %%
x = np.arange(0, 100)
y = x**2 #np.exp(x) + 100
z = np.exp(x)

fig, [ax1, ax2] = plt.subplots(1,2, figsize=(15,2))
ax1.plot(x,y, color='r')
ax1.set_title('X * 2 PLOT')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')
ax1.set_xscale("linear")
ax1.set_yscale("linear")

ax2.plot(x,z, color='b')
ax2.set_title('X^2 PLOT')
ax2.set_xlabel('x label')
ax2.set_ylabel('y label')
ax2.set_xscale("log")
ax2.set_yscale("log")

# %% [markdown]
# #### In the vehicles data set that you have downloaded, conduct exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart. Please provide at least one inssight from the plot that you have drawn

# %%
vehicles = pd.read_csv("vehicles.csv")

vehicles.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %% [markdown]
# Scatter Plot

# %%
# your code here
df = vehicles
from scipy.interpolate import interp1d


x = df['Year']
y = df['CO2 Emission Grams/Mile']
f = interp1d(x, y)


x_new = np.arange(df['Year'].min(), df['Year'].max())
#plt.plot(x_new, f(x_new))

g = interp1d(x, y, 'linear')
plt.scatter(x, g(x), color="red")

# %% [markdown]
# Box Whisker Plot

# %%
# your code here

fig1, ax1 = plt.subplots()
ax1.set_title('Cylinders')
ax1.boxplot(df["Cylinders"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a24ea7cc0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a24eb3400>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a24ea7860>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a24eb3b00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a24eb3e80>],
#  'means': []}

# %% [markdown]
# Histogram

# %%
# your code here
df = vehicles.head()
ax = df["City MPG"].plot.hist(bins=12, alpha=0.5)

# %% [markdown]
# Bar Chart

# %%
# your code here
df = vehicles.head()

df.plot.bar(x="Year", y="Fuel Cost/Year", rot=0)
