# %% [markdown]
# # Import Librairies

# %%
import numpy as np

# %%
divorces = pd.read_csv('divorce-csv.csv')

divorces.head()
# Out:
#    Atr1  Atr2  Atr3  Atr4  Atr5  Atr6  Atr7  Atr8  Atr9  Atr10  ...  Atr46  \
# 0     2     2     4     1     0     0     0     0     0      0  ...      2
# 1     4     4     4     4     4     0     0     4     4      4  ...      2
# 2     2     2     2     2     1     3     2     1     1      2  ...      3
# 3     3     2     3     2     3     3     3     3     3      3  ...      2
# 4     2     2     1     1     1     1     0     0     0      0  ...      2
#
#    Atr47  Atr48  Atr49  Atr50  Atr51  Atr52  Atr53  Atr54  Class
# 0      1      3      3      3      2      3      2      1      1
# 1      2      3      4      4      4      4      2      2      1
# 2      2      3      1      1      1      2      2      2      1
# 3      2      3      3      3      3      2      2      2      1
# 4      1      2      3      2      2      2      1      0      1
#
# [5 rows x 55 columns]

# %%
divorces.shape
# Out:
# (170, 55)

# %%
columns_personality = pd.read_csv('columns.csv')

columns_personality.head()
# Out:
#                       original                     short
# 0  I enjoy listening to music.                     Music
# 1                    I prefer.  Slow songs or fast songs
# 2           Dance, Disco, Funk                     Dance
# 3                   Folk music                      Folk
# 4                      Country                   Country

# %%
personalities = pd.read_csv('responses.csv')

personalities.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# 0      1.0  5.0   5.0                1.0  ...  20.0   163.0    48.0
# 1      2.0  3.0   5.0                4.0  ...  19.0   163.0    58.0
# 2      5.0  3.0   5.0                3.0  ...  20.0   176.0    67.0
# 3      1.0  2.0   2.0                1.0  ...  22.0   172.0    59.0
# 4      3.0  5.0   3.0                1.0  ...  20.0   170.0    59.0
#
#    Number of siblings  Gender  Left - right handed                Education  \
# 0                 1.0  female         right handed  college/bachelor degree
# 1                 2.0  female         right handed  college/bachelor degree
# 2                 2.0  female         right handed         secondary school
# 3                 1.0  female         right handed  college/bachelor degree
# 4                 1.0  female         right handed         secondary school
#
#    Only child  Village - town  House - block of flats
# 0          no         village          block of flats
# 1          no            city          block of flats
# 2          no            city          block of flats
# 3         yes            city          house/bungalow
# 4          no         village          house/bungalow
#
# [5 rows x 150 columns]

# %%
personalities.shape
# Out:
# (1010, 150)

# %% [markdown]
# ## The Data

# %% [markdown]
# The Kaggle dataset I used for this project is the result of a survey asked in 2013 to students.
# This survey is about personalities (hobbies, musics and movies preferences, phobies, personalities traits and characteristics...).
# All participants were of Slovakian nationality, aged between 15-30.
#
# As the column name of this dataset was shortened so that I used a second dataset to have the definition of each column.
#
# The question is how could we group this student, could we see similar paterns or correlation between data.
#
# [Link of the dataset](https://www.kaggle.com/miroslavsabo/young-people-survey)

# %% [markdown]
# ## Data Ingestion

# %% [markdown]
# In this part I will analyze deeper the dataset.
#
# I will read the dataset and analyze
#
# We have 1010 rows and 150 columns (139 integer and 11 categorical)

# %%
import pandas as pd

personalities = pd.read_csv('responses.csv')
personalities.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# 0      1.0  5.0   5.0                1.0  ...  20.0   163.0    48.0
# 1      2.0  3.0   5.0                4.0  ...  19.0   163.0    58.0
# 2      5.0  3.0   5.0                3.0  ...  20.0   176.0    67.0
# 3      1.0  2.0   2.0                1.0  ...  22.0   172.0    59.0
# 4      3.0  5.0   3.0                1.0  ...  20.0   170.0    59.0
#
#    Number of siblings  Gender  Left - right handed                Education  \
# 0                 1.0  female         right handed  college/bachelor degree
# 1                 2.0  female         right handed  college/bachelor degree
# 2                 2.0  female         right handed         secondary school
# 3                 1.0  female         right handed  college/bachelor degree
# 4                 1.0  female         right handed         secondary school
#
#    Only child  Village - town  House - block of flats
# 0          no         village          block of flats
# 1          no            city          block of flats
# 2          no            city          block of flats
# 3         yes            city          house/bungalow
# 4          no         village          house/bungalow
#
# [5 rows x 150 columns]

# %%
personalities.shape
# Out:
# (1010, 150)

# %%
personalities.columns.tolist()
# Out:
# ['Music',
#  'Slow songs or fast songs',
#  'Dance',
#  'Folk',
#  'Country',
#  'Classical music',
#  'Musical',
#  'Pop',
#  'Rock',
#  'Metal or Hardrock',
#  'Punk',
#  'Hiphop, Rap',
#  'Reggae, Ska',
#  'Swing, Jazz',
#  'Rock n roll',
#  'Alternative',
#  'Latino',
#  'Techno, Trance',
#  'Opera',
#  'Movies',
#  'Horror',
#  'Thriller',
#  'Comedy',
#  'Romantic',
#  'Sci-fi',
#  'War',
#  'Fantasy/Fairy tales',
#  'Animated',
#  'Documentary',
#  'Western',
#  'Action',
#  'History',
#  'Psychology',
#  'Politics',
#  'Mathematics',
#  'Physics',
#  'Internet',
#  'PC',
#  'Economy Management',
#  'Biology',
#  'Chemistry',
#  'Reading',
#  'Geography',
#  'Foreign languages',
#  'Medicine',
#  'Law',
#  'Cars',
#  'Art exhibitions',
#  'Religion',
#  'Countryside, outdoors',
#  'Dancing',
#  'Musical instruments',
#  'Writing',
#  'Passive sport',
#  'Active sport',
#  'Gardening',
#  'Celebrities',
#  'Shopping',
#  'Science and technology',
#  'Theatre',
#  'Fun with friends',
#  'Adrenaline sports',
#  'Pets',
#  'Flying',
#  'Storm',
#  'Darkness',
#  'Heights',
#  'Spiders',
#  'Snakes',
#  'Rats',
#  'Ageing',
#  'Dangerous dogs',
#  'Fear of public speaking',
#  'Smoking',
#  'Alcohol',
#  'Healthy eating',
#  'Daily events',
#  'Prioritising workload',
#  'Writing notes',
#  'Workaholism',
#  'Thinking ahead',
#  'Final judgement',
#  'Reliability',
#  'Keeping promises',
#  'Loss of interest',
#  'Friends versus money',
#  'Funniness',
#  'Fake',
#  'Criminal damage',
#  'Decision making',
#  'Elections',
#  'Self-criticism',
#  'Judgment calls',
#  'Hypochondria',
#  'Empathy',
#  'Eating to survive',
#  'Giving',
#  'Compassion to animals',
#  'Borrowed stuff',
#  'Loneliness',
#  'Cheating in school',
#  'Health',
#  'Changing the past',
#  'God',
#  'Dreams',
#  'Charity',
#  'Number of friends',
#  'Punctuality',
#  'Lying',
#  'Waiting',
#  'New environment',
#  'Mood swings',
#  'Appearence and gestures',
#  'Socializing',
#  'Achievements',
#  'Responding to a serious letter',
#  'Children',
#  'Assertiveness',
#  'Getting angry',
#  'Knowing the right people',
#  'Public speaking',
#  'Unpopularity',
#  'Life struggles',
#  'Happiness in life',
#  'Energy levels',
#  'Small - big dogs',
#  'Personality',
#  'Finding lost valuables',
#  'Getting up',
#  'Interests or hobbies',
#  "Parents' advice",
#  'Questionnaires or polls',
#  'Internet usage',
#  'Finances',
#  'Shopping centres',
#  'Branded clothing',
#  'Entertainment spending',
#  'Spending on looks',
#  'Spending on gadgets',
#  'Spending on healthy eating',
#  'Age',
#  'Height',
#  'Weight',
#  'Number of siblings',
#  'Gender',
#  'Left - right handed',
#  'Education',
#  'Only child',
#  'Village - town',
#  'House - block of flats']

# %%
personalities.dtypes
# Out:
# Music                         float64
# Slow songs or fast songs      float64
# Dance                         float64
# Folk                          float64
# Country                       float64
# Classical music               float64
# Musical                       float64
# Pop                           float64
# Rock                          float64
# Metal or Hardrock             float64
# Punk                          float64
# Hiphop, Rap                   float64
# Reggae, Ska                   float64
# Swing, Jazz                   float64
# Rock n roll                   float64
# Alternative                   float64
# Latino                        float64
# Techno, Trance                float64
# Opera                         float64
# Movies                        float64
# Horror                        float64
# Thriller                      float64
# Comedy                        float64
# Romantic                      float64
# Sci-fi                        float64
# War                           float64
# Fantasy/Fairy tales           float64
# Animated                      float64
# Documentary                   float64
# Western                       float64
#                                ...
# Public speaking               float64
# Unpopularity                  float64
# Life struggles                float64
# Happiness in life             float64
# Energy levels                 float64
# Small - big dogs              float64
# Personality                   float64
# Finding lost valuables        float64
# Getting up                    float64
# Interests or hobbies          float64
# Parents' advice               float64
# Questionnaires or polls       float64
# Internet usage                 object
# Finances                      float64
# Shopping centres              float64
# Branded clothing              float64
# Entertainment spending        float64
# Spending on looks             float64
# Spending on gadgets             int64
# Spending on healthy eating    float64
# Age                           float64
# Height                        float64
# Weight                        float64
# Number of siblings            float64
# Gender                         object
# Left - right handed            object
# Education                      object
# Only child                     object
# Village - town                 object
# House - block of flats         object
# Length: 150, dtype: object

# %%
null_cols = personalities.isnull().sum()

null_cols[null_cols > 0]
# Out:
# Music                          3
# Slow songs or fast songs       2
# Dance                          4
# Folk                           5
# Country                        5
# Classical music                7
# Musical                        2
# Pop                            3
# Rock                           6
# Metal or Hardrock              3
# Punk                           8
# Hiphop, Rap                    4
# Reggae, Ska                    7
# Swing, Jazz                    6
# Rock n roll                    7
# Alternative                    7
# Latino                         8
# Techno, Trance                 7
# Opera                          1
# Movies                         6
# Horror                         2
# Thriller                       1
# Comedy                         3
# Romantic                       3
# Sci-fi                         2
# War                            2
# Fantasy/Fairy tales            3
# Animated                       3
# Documentary                    8
# Western                        4
#                               ..
# Getting angry                  4
# Knowing the right people       2
# Public speaking                2
# Unpopularity                   3
# Life struggles                 3
# Happiness in life              4
# Energy levels                  5
# Small - big dogs               4
# Personality                    4
# Finding lost valuables         4
# Getting up                     5
# Interests or hobbies           3
# Parents' advice                2
# Questionnaires or polls        4
# Finances                       3
# Shopping centres               2
# Branded clothing               2
# Entertainment spending         3
# Spending on looks              3
# Spending on healthy eating     2
# Age                            7
# Height                        20
# Weight                        20
# Number of siblings             6
# Gender                         6
# Left - right handed            3
# Education                      1
# Only child                     2
# Village - town                 4
# House - block of flats         4
# Length: 144, dtype: int64

# %%
null_rows = personalities[personalities.isnull().any(axis=1)]
null_rows
# Out:
#       Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 3       5.0                       3.0    2.0   1.0      1.0              1.0
# 8       5.0                       3.0    3.0   1.0      1.0              2.0
# 15      1.0                       3.0    2.0   2.0      3.0              4.0
# 17      5.0                       3.0    3.0   3.0      3.0              2.0
# 22      5.0                       3.0    3.0   2.0      3.0              3.0
# 27      4.0                       5.0    3.0   4.0      1.0              3.0
# 37      5.0                       5.0    1.0   1.0      1.0              5.0
# 45      5.0                       4.0    5.0   2.0      2.0              4.0
# 46      5.0                       3.0    4.0   3.0      4.0              1.0
# 47      5.0                       3.0    3.0   1.0      1.0              2.0
# 51      5.0                       3.0    3.0   3.0      1.0              4.0
# 56      5.0                       3.0    1.0   2.0      3.0              4.0
# 58      5.0                       5.0    5.0   3.0      2.0              3.0
# 63      5.0                       4.0    NaN   1.0      3.0              2.0
# 69      5.0                       4.0    1.0   1.0      1.0              1.0
# 72      5.0                       3.0    2.0   2.0      2.0              2.0
# 76      4.0                       4.0    4.0   1.0      1.0              2.0
# 78      4.0                       4.0    4.0   2.0      4.0              1.0
# 83      5.0                       3.0    5.0   1.0      2.0              4.0
# 84      5.0                       3.0    1.0   1.0      4.0              5.0
# 87      5.0                       4.0    4.0   1.0      2.0              2.0
# 91      5.0                       5.0    1.0   5.0      1.0              NaN
# 93      5.0                       4.0    1.0   5.0      5.0              4.0
# 94      5.0                       5.0    5.0   1.0      1.0              1.0
# 102     5.0                       3.0    1.0   2.0      3.0              5.0
# 103     5.0                       5.0    5.0   2.0      2.0              NaN
# 107     5.0                       3.0    1.0   1.0      1.0              2.0
# 113     3.0                       4.0    4.0   2.0      3.0              1.0
# 115     5.0                       4.0    5.0   2.0      2.0              5.0
# 124     4.0                       4.0    1.0   4.0      NaN              5.0
# ...     ...                       ...    ...   ...      ...              ...
# 941     5.0                       3.0    3.0   2.0      1.0              2.0
# 942     5.0                       2.0    5.0   3.0      2.0              4.0
# 943     4.0                       3.0    3.0   2.0      1.0              5.0
# 945     5.0                       2.0    5.0   2.0      3.0              3.0
# 946     5.0                       5.0    2.0   1.0      2.0              4.0
# 948     5.0                       3.0    4.0   3.0      2.0              3.0
# 949     5.0                       3.0    3.0   2.0      3.0              1.0
# 950     5.0                       3.0    2.0   3.0      NaN              4.0
# 951     4.0                       3.0    4.0   1.0      1.0              1.0
# 954     5.0                       3.0    5.0   3.0      2.0              2.0
# 956     5.0                       4.0    3.0   1.0      4.0              3.0
# 958     5.0                       5.0    5.0   3.0      1.0              3.0
# 960     5.0                       3.0    4.0   4.0      1.0              5.0
# 963     4.0                       4.0    4.0   3.0      3.0              5.0
# 964     5.0                       4.0    3.0   2.0      3.0              3.0
# 965     5.0                       5.0    5.0   3.0      3.0              3.0
# 968     5.0                       4.0    3.0   2.0      2.0              3.0
# 975     5.0                       3.0    5.0   5.0      5.0              5.0
# 980     5.0                       3.0    2.0   2.0      2.0              5.0
# 983     5.0                       4.0    3.0   1.0      1.0              3.0
# 984     5.0                       2.0    1.0   3.0      2.0              3.0
# 987     4.0                       3.0    2.0   2.0      3.0              2.0
# 988     5.0                       2.0    3.0   2.0      2.0              5.0
# 993     5.0                       3.0    3.0   1.0      2.0              3.0
# 994     5.0                       4.0    3.0   2.0      2.0              3.0
# 996     5.0                       3.0    1.0   1.0      1.0              3.0
# 997     5.0                       4.0    3.0   3.0      3.0              1.0
# 999     5.0                       5.0    5.0   3.0      4.0              5.0
# 1002    5.0                       5.0    3.0   1.0      3.0              1.0
# 1006    4.0                       4.0    5.0   1.0      3.0              4.0
#
#       Musical  Pop  Rock  Metal or Hardrock  ...   Age  Height  Weight  \
# 3         1.0  2.0   2.0                1.0  ...  22.0   172.0    59.0
# 8         4.0  3.0   5.0                5.0  ...  18.0   166.0    55.0
# 15        3.0  3.0   5.0                5.0  ...  18.0   177.0    77.0
# 17        2.0  4.0   4.0                2.0  ...  20.0   168.0    65.0
# 22        3.0  4.0   NaN                1.0  ...  22.0   167.0    70.0
# 27        2.0  2.0   4.0                2.0  ...  19.0   163.0    50.0
# 37        1.0  2.0   3.0                5.0  ...  21.0   185.0   101.0
# 45        3.0  5.0   4.0                1.0  ...  27.0   181.0    78.0
# 46        5.0  5.0   5.0                3.0  ...  21.0   163.0    55.0
# 47        3.0  4.0   4.0                2.0  ...  19.0   170.0    60.0
# 51        3.0  5.0   4.0                3.0  ...  19.0     NaN    75.0
# 56        3.0  4.0   5.0                1.0  ...  20.0   170.0    64.0
# 58        2.0  5.0   1.0                1.0  ...  19.0   185.0    71.0
# 63        1.0  2.0   3.0                1.0  ...  22.0   180.0    78.0
# 69        4.0  5.0   4.0                1.0  ...  20.0   163.0    47.0
# 72        5.0  5.0   5.0                2.0  ...  28.0   168.0    52.0
# 76        2.0  2.0   2.0                1.0  ...  18.0   188.0    75.0
# 78        5.0  5.0   3.0                1.0  ...  24.0   148.0    57.0
# 83        4.0  5.0   5.0                3.0  ...  22.0   163.0    53.0
# 84        5.0  1.0   5.0                5.0  ...  19.0   168.0    48.0
# 87        4.0  4.0   5.0                2.0  ...  18.0   159.0    50.0
# 91        5.0  3.0   5.0                5.0  ...  18.0   168.0    50.0
# 93        4.0  4.0   3.0                3.0  ...  24.0   175.0    80.0
# 94        2.0  4.0   3.0                1.0  ...  21.0   179.0    68.0
# 102       4.0  1.0   5.0                2.0  ...  20.0   168.0    55.0
# 103       4.0  5.0   1.0                1.0  ...  22.0   185.0    80.0
# 107       2.0  2.0   4.0                4.0  ...  18.0   178.0    55.0
# 113       2.0  4.0   4.0                2.0  ...  21.0   162.0    60.0
# 115       4.0  5.0   5.0                2.0  ...  17.0   175.0    62.0
# 124       5.0  3.0   5.0                3.0  ...  20.0   176.0    69.0
# ...       ...  ...   ...                ...  ...   ...     ...     ...
# 941       2.0  4.0   4.0                3.0  ...  18.0   172.0    55.0
# 942       1.0  4.0   2.0                1.0  ...  24.0   175.0    71.0
# 943       2.0  3.0   NaN                1.0  ...  22.0   182.0    83.0
# 945       3.0  4.0   4.0                4.0  ...  22.0   180.0    70.0
# 946       3.0  3.0   5.0                5.0  ...  22.0   193.0   100.0
# 948       4.0  4.0   3.0                1.0  ...  18.0   170.0    75.0
# 949       2.0  3.0   4.0                3.0  ...  18.0   164.0    56.0
# 950       2.0  4.0   5.0                5.0  ...  15.0   190.0    85.0
# 951       1.0  4.0   3.0                2.0  ...  26.0   186.0    76.0
# 954       3.0  3.0   3.0                1.0  ...  20.0   175.0    62.0
# 956       4.0  4.0   4.0                3.0  ...  20.0   178.0    83.0
# 958       3.0  4.0   1.0                1.0  ...  22.0   169.0    59.0
# 960       1.0  3.0   5.0                5.0  ...   NaN     NaN     NaN
# 963       1.0  5.0   4.0                1.0  ...  23.0   185.0    92.0
# 964       3.0  3.0   5.0                5.0  ...  21.0     NaN    75.0
# 965       5.0  5.0   5.0                2.0  ...  17.0   170.0    65.0
# 968       3.0  4.0   3.0                2.0  ...  19.0   184.0    75.0
# 975       5.0  5.0   5.0                5.0  ...  23.0   175.0    85.0
# 980       1.0  4.0   4.0                4.0  ...  18.0   166.0    53.0
# 983       3.0  5.0   3.0                1.0  ...  22.0   172.0    60.0
# 984       3.0  3.0   4.0                4.0  ...  21.0   165.0    55.0
# 987       1.0  1.0   5.0                3.0  ...  20.0   184.0    80.0
# 988       2.0  2.0   5.0                2.0  ...  19.0   183.0    70.0
# 993       1.0  4.0   4.0                1.0  ...  21.0   173.0    55.0
# 994       4.0  3.0   5.0                3.0  ...  20.0   176.0    78.0
# 996       2.0  1.0   4.0                3.0  ...  20.0   190.0    74.0
# 997       3.0  3.0   4.0                2.0  ...  19.0   167.0    53.0
# 999       4.0  4.0   4.0                3.0  ...  19.0   181.0    70.0
# 1002      1.0  2.0   5.0                5.0  ...  22.0   181.0    72.0
# 1006      1.0  4.0   1.0                1.0  ...  27.0   183.0    80.0
#
#       Number of siblings  Gender  Left - right handed  \
# 3                    1.0  female         right handed
# 8                    1.0  female         right handed
# 15                   0.0    male         right handed
# 17                   1.0  female         right handed
# 22                   1.0  female         right handed
# 27                   1.0  female         right handed
# 37                   1.0    male         right handed
# 45                   1.0    male         right handed
# 46                   1.0  female         right handed
# 47                   1.0  female         right handed
# 51                   1.0  female         right handed
# 56                   2.0  female          left handed
# 58                   1.0    male         right handed
# 63                   2.0    male         right handed
# 69                   3.0  female          left handed
# 72                   1.0  female         right handed
# 76                   1.0    male         right handed
# 78                   1.0  female         right handed
# 83                   2.0  female         right handed
# 84                   0.0  female         right handed
# 87                   3.0  female         right handed
# 91                   4.0  female         right handed
# 93                   2.0    male         right handed
# 94                   1.0    male         right handed
# 102                  0.0  female         right handed
# 103                  0.0    male         right handed
# 107                  1.0  female         right handed
# 113                  1.0  female         right handed
# 115                  0.0  female         right handed
# 124                  4.0    male         right handed
# ...                  ...     ...                  ...
# 941                  3.0  female         right handed
# 942                  0.0    male         right handed
# 943                  2.0  female         right handed
# 945                  1.0    male         right handed
# 946                  0.0    male         right handed
# 948                  1.0  female         right handed
# 949                  3.0  female         right handed
# 950                  0.0    male          left handed
# 951                  3.0    male         right handed
# 954                  0.0  female         right handed
# 956                  2.0    male         right handed
# 958                  2.0  female         right handed
# 960                  NaN  female         right handed
# 963                  0.0    male          left handed
# 964                  3.0    male         right handed
# 965                  2.0  female         right handed
# 968                  2.0    male          left handed
# 975                  1.0  female         right handed
# 980                  2.0  female         right handed
# 983                  2.0  female         right handed
# 984                  1.0  female         right handed
# 987                  1.0    male         right handed
# 988                  0.0    male         right handed
# 993                  0.0  female         right handed
# 994                  0.0  female         right handed
# 996                  0.0    male         right handed
# 997                  1.0  female         right handed
# 999                  1.0    male         right handed
# 1002                 1.0    male         right handed
# 1006                 5.0    male          left handed
#
#                              Education  Only child  Village - town  \
# 3              college/bachelor degree         yes            city
# 8                     secondary school          no            city
# 15                    secondary school         yes            city
# 17                    secondary school          no         village
# 22             college/bachelor degree          no            city
# 27                    secondary school          no            city
# 37                    secondary school          no            city
# 45                      masters degree          no             NaN
# 46             college/bachelor degree          no            city
# 47                    secondary school         yes            city
# 51                    secondary school          no            city
# 56                    secondary school         NaN            city
# 58                    secondary school          no         village
# 63             college/bachelor degree          no            city
# 69                    secondary school          no            city
# 72                    secondary school          no            city
# 76                    secondary school          no            city
# 78             college/bachelor degree          no         village
# 83                    secondary school          no            city
# 84                    secondary school         yes            city
# 87             college/bachelor degree          no         village
# 91                    secondary school          no         village
# 93                      masters degree          no         village
# 94                    secondary school          no            city
# 102                   secondary school         yes            city
# 103                   secondary school         yes            city
# 107                   secondary school          no            city
# 113            college/bachelor degree          no         village
# 115                   secondary school         yes            city
# 124                   secondary school          no            city
# ...                                ...         ...             ...
# 941                     primary school          no         village
# 942            college/bachelor degree         yes         village
# 943                   secondary school          no            city
# 945                   secondary school          no            city
# 946                   secondary school         yes            city
# 948                   secondary school          no         village
# 949                   secondary school          no            city
# 950   currently a primary school pupil         yes         village
# 951                     masters degree          no            city
# 954                   secondary school          no            city
# 956                   secondary school         yes            city
# 958            college/bachelor degree          no            city
# 960                     masters degree          no            city
# 963                   secondary school         yes            city
# 964            college/bachelor degree         yes            city
# 965                     primary school          no            city
# 968                   secondary school          no            city
# 975                   secondary school         yes         village
# 980                   secondary school          no            city
# 983                   secondary school          no         village
# 984                   secondary school         yes            city
# 987                   secondary school          no            city
# 988                   secondary school         yes            city
# 993                   secondary school         yes            city
# 994                   secondary school         yes            city
# 996                   secondary school         yes             NaN
# 997                   secondary school          no             NaN
# 999                   secondary school          no            city
# 1002                  secondary school          no            city
# 1006                    masters degree          no         village
#
#       House - block of flats
# 3             house/bungalow
# 8             house/bungalow
# 15            block of flats
# 17            house/bungalow
# 22            house/bungalow
# 27            house/bungalow
# 37            block of flats
# 45            block of flats
# 46            block of flats
# 47            house/bungalow
# 51            block of flats
# 56            block of flats
# 58            house/bungalow
# 63            block of flats
# 69            block of flats
# 72            block of flats
# 76                       NaN
# 78            house/bungalow
# 83            block of flats
# 84            block of flats
# 87            house/bungalow
# 91            house/bungalow
# 93            house/bungalow
# 94            block of flats
# 102           block of flats
# 103           house/bungalow
# 107           house/bungalow
# 113           house/bungalow
# 115           block of flats
# 124           block of flats
# ...                      ...
# 941           house/bungalow
# 942           house/bungalow
# 943           block of flats
# 945           block of flats
# 946           house/bungalow
# 948           house/bungalow
# 949           block of flats
# 950           house/bungalow
# 951           block of flats
# 954           block of flats
# 956           house/bungalow
# 958           block of flats
# 960           block of flats
# 963           block of flats
# 964           block of flats
# 965           block of flats
# 968           house/bungalow
# 975           block of flats
# 980           house/bungalow
# 983           house/bungalow
# 984           block of flats
# 987           block of flats
# 988           block of flats
# 993           block of flats
# 994           block of flats
# 996           block of flats
# 997           block of flats
# 999           block of flats
# 1002          block of flats
# 1006          house/bungalow
#
# [336 rows x 150 columns]

# %% [markdown]
# ## Data Wrangling and Cleaning
