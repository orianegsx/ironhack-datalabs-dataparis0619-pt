# %% [markdown]
# 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# 2. Read csv you downloaded to import data and rename the columns

# %%
#We define the csv path
data_url = "GSAF5.csv"

#We read the csv and assign to a dataFrame
df = pd.read_csv(data_url, sep=';', encoding='latin1')

#We display the first rows to visualize our data
df
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
#Analyze missing value
null_cols = df.isnull().sum()
null_cols[null_cols > 0]
# Out:
# Case Number                  9
# Date                         2
# Year                         3
# Type                         1
# Country                     44
# Area                       402
# Location                   498
# Activity                   533
# Name                       210
# Sex                        581
# Age                       2682
# Injury                      51
# Fatal (Y/N)                108
# Time                      3227
# Species                   2979
# Investigator or Source     120
# pdf                       1503
# href formula              1503
# href                      1506
# Case Number.1             1503
# Case Number.2             1503
# original order            1503
# Unnamed: 22               5981
# Unnamed: 23               5981
# dtype: int64

# %%
df['Activity']
# Out:
# 0                                                 Surfing
# 1                                                 Surfing
# 2                                                 Surfing
# 3                                                 Surfing
# 4                                                 Surfing
# 5                                                 Fishing
# 6                                                  Wading
# 7                                                Swimming
# 8                                            Kite surfing
# 9                                         Boogie boarding
# 10                                                Surfing
# 11                                          Body boarding
# 12                                           Spearfishing
# 13                                                Surfing
# 14                                                Surfing
# 15                                                Surfing
# ...

# %%
#How many rows do we have?
df.shape
# Out:
# (5983, 24)

# %%
#We have 2 columns ('Unnamed cols') that we want to drop because they have more than 5000 null value
drop_cols = list(null_cols[null_cols > 5000].index)
df = df.drop(drop_cols, axis=1)
df
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
#We want to know if the cells Case Number 1 and Case number 2 are null at the same time
null_displ = df[(df['Case Number.1'].isnull()==True)]
null_displ = null_displ[['Case Number.1','Case Number.2']]
null_displ
# Out:
#      Case Number.1 Case Number.2
# 57             NaN           NaN
# 58             NaN           NaN
# 107            NaN           NaN
# 184            NaN           NaN
# 189            NaN           NaN
# 216            NaN           NaN
# 239            NaN           NaN
# 269            NaN           NaN
# 270            NaN           NaN
# 271            NaN           NaN
# 294            NaN           NaN
# 301            NaN           NaN
# 319            NaN           NaN
# 356            NaN           NaN
# 379            NaN           NaN
# 383            NaN           NaN
# 425            NaN           NaN
# 432            NaN           NaN
# 460            NaN           NaN
# 467            NaN           NaN
# 470            NaN           NaN
# 484            NaN           NaN
# 506            NaN           NaN
# 536            NaN           NaN
# 546            NaN           NaN
# 605            NaN           NaN
# 634            NaN           NaN
# ...

# %%
#Seems that href formula and href are the same data

# %%
#We can drop these useless columns
df = df.drop(['Case Number.1','Case Number.2', 'href'], axis=1)
df
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
#No need to fill in the columns because it is not a count value
#data[['Age', 'Species']] = data[['Age', 'Species']].fillna(0)

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula',
#        'original order'],
#       dtype='object')

# %%
print(set(df['Sex ']))
# Out:
# {nan, 'M', 'N', '2016.05.29.b-Corona.pdf', 'M ', 'lli', 'Occupant: Hasan Olta', '.', '2014.10.11-Dunsborough.pdf', '1931.03.15-Turkey.pdf', 'F'}

# %%
print(set(df['Fatal (Y/N)']))
# Out:
# {nan, 'N ', 'N', 'Y', '#VALUE!', '2016.05.29.b', 'UNKNOWN', 'n', '1931.03.15', 'No injury ', 'F', '2014.10.11', ' N'}

# %%
df['Sex '] = df['Sex '].str.replace(' ', '')
df['Fatal (Y/N)'] = df['Fatal (Y/N)'].str.replace(' ', '')



#dataframe['Sex'].map({'m': 'male', 'fem.': 'female', ...})

# %%
print(set(df['Age']))
# Out:
# {nan, '48', '20', '69', '20s', '16', '>50', 'X', ' ', 'MAKE LINE GREEN', '44', '21', '31', '15', '64', '56', '49', '17 & 35', '10 or 12', '31 or 33', '41', '62', '17 & 16', '67', '70', '60', '30s', '14', '50 & 30', '73', '23 & 20', '72', '6', 'Both 11', "60's", 'mid-20s', 'Teens', '74', '36 & 26', '19', '35', '24', '7      &    31', '47', '45', '25 or 28', '12', 'F', '? & 19', '36', '25', '2 to 3 months', '40s', 'A.M.', '28 & 26', '17', '30 or 36', '87', '23 & 26', 'Elderly', '?    &   14', 'http://sharkattackfile.net/spreadsheets/pdf_directory/1931.03.15-Turkey.pdf', '20?', '18 to 22', '26', '53', '38', '39', '60s', '55', '52', '65', '9', '3', 'mid-30s', '43', '9 or 10', '21 or 26', '30', '71', '1', 'M', '27', '30 & 32', '8', '57', '13 or 14', '33', '7', 'Ca. 33', '77', '9 & 12', 'http://sharkattackfile.net/spreadsheets/pdf_directory/2014.10.11-Dunsborough.pdf', '32', '2½', '58', '6½', '28, 23 & 30', '34 & 19', '11', '54', '29', '5', '25 to 35', '50s', '"young"', '10', '7 or 8', '75
# ...

# %%
df.loc[(df['Name']=='male') & (df['Sex ']!=0), 'Sex '] = 'M'
df.loc[(df['Name']=='female') & (df['Sex ']!=0), 'Sex '] = 'M'

# %%
# Out:
# {nan, 'M', 'N', '2016.05.29.b-Corona.pdf', 'M ', 'lli', 'Occupant: Hasan Olta', '.', '2014.10.11-Dunsborough.pdf', '1931.03.15-Turkey.pdf', 'F'}

# %%
print(set(df['Sex ']))
# Out:
# {nan, 'M', 'N', '2016.05.29.b-Corona.pdf', '.', 'lli', '2014.10.11-Dunsborough.pdf', 'Occupant:HasanOlta', '1931.03.15-Turkey.pdf', 'F'}

# %%
low_variance = []

for col in df._get_numeric_data():
    minimum = min(df[col])
    ninety_perc = np.percentile(df[col], 70)
    if ninety_perc == minimum:
        low_variance.append(col)

print(low_variance)
# Out:
# []

# %%
#stats = df.describe().transpose()
#stats['IQR'] = stats['75%'] - stats['25%']
#stats

outliers = pd.DataFrame(columns=df.columns)

for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 1.5
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = data[(df[col] < lower) | 
                   (df[col] > upper)].copy()
    results['Outlier'] = col
    outliers = outliers.append(results)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'IQR'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-156-98e511bfb9bb> in <module>
#       6
#       7 for col in stats.index:
# ...

# %%
before = len(df)
df = df.drop_duplicates()
after = len(df)
print('Number of duplicate records dropped: ', str(before - after))
# Out:
# Number of duplicate records dropped:  0

# %%
df.dtypes
# Out:
# Case Number               object
# Date                      object
# Year                      object
# Type                      object
# Country                   object
# Area                      object
# Location                  object
# Activity                  object
# Name                      object
# Sex                       object
# Age                       object
# Injury                    object
# Fatal (Y/N)               object
# Time                      object
# Species                   object
# Investigator or Source    object
# pdf                       object
# href formula              object
# original order            object
# dtype: object

# %%
df['Date'] = df['Date'].astype('datetime64[ns]')
df['Date'].dtype
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1860         try:
# -> 1861             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1862             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-165-f0fdb03b8764> in <module>
# ----> 1 df['Date'] = df['Date'].astype('datetime64[ns]')
#       2 df['Date'].dtype
#       3
#
# ...

# %%
df.Date = pd.to_numeric(df.Date, errors='coerce')
data.Power = pd.to_numeric(data.Power, errors='coerce').fillna(0).astype(int)
print(set(df['Date']))

# %%
var = '2017'

var == r"[0-9]{4}"
# Out:
# False

# %%
b = "Before 1963"

import re

c = b.replace('Reported', '').split('Before')[-1].strip()

d = re.sub(r'.*Before', '', b).strip()
