# %% [markdown]
# # Challenge 1: Web Data Pipeline

# %% [markdown]
# 1. Import librairies

# %%
import pandas as pd
import matplotlib

# %% [markdown]
# 2. Transform your .csv into a dataFrame

# %%
data_url = "train_clean.csv"
df = pd.read_csv(data_url)
df
# Out:
#       Age        Cabin Embarked      Fare  \
# 0    22.0          NaN        S    7.2500
# 1    38.0          C85        C   71.2833
# 2    26.0          NaN        S    7.9250
# 3    35.0         C123        S   53.1000
# 4    35.0          NaN        S    8.0500
# 5    30.0          NaN        Q    8.4583
# 6    54.0          E46        S   51.8625
# 7     2.0          NaN        S   21.0750
# 8    27.0          NaN        S   11.1333
# 9    14.0          NaN        C   30.0708
# 10    4.0           G6        S   16.7000
# 11   58.0         C103        S   26.5500
# 12   20.0          NaN        S    8.0500
# 13   39.0          NaN        S   31.2750
# 14   14.0          NaN        S    7.8542
# 15   55.0          NaN        S   16.0000
# 16    2.0          NaN        Q   29.1250
# 17   30.0          NaN        S   13.0000
# 18   31.0          NaN        S   18.0000
# 19   35.5          NaN        C    7.2250
# 20   35.0          NaN        S   26.0000
# ...

# %% [markdown]
# 3. Verify is columns have null values, in percentage

# %%
null_cols = df.isnull().sum()
null_cols[null_cols > 0]
# Out:
# Cabin    687
# dtype: int64

# %%
percentage = float(df['Cabin'].isnull().sum() / df['Cabin'].count())
percentage
# Out:
# 3.3676470588235294

# %% [markdown]
# 4. Analyse the global age of people

# %%
# %matplotlib inline

df.boxplot('Age')

# %%
df.hist('Age')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x123c914a8>]],
#       dtype=object)

# %% [markdown]
# 5. Analyse the title of people

# %%
df.columns
# Out:
# Index(['Age', 'Cabin', 'Embarked', 'Fare', 'Name', 'Parch', 'PassengerId',
#        'Pclass', 'Sex', 'SibSp', 'Survived', 'Ticket', 'Title', 'Family_Size'],
#       dtype='object')

# %%
print(set(df['Title']))
# Out:
# {'Mrs', 'Mr', 'Master', 'Rev', 'Dr', 'Miss'}

# %%
df["Title"].value_counts()
# Out:
# Mr        525
# Miss      185
# Mrs       128
# Master     40
# Dr          7
# Rev         6
# Name: Title, dtype: int64

# %% [markdown]
# 6. Calculate the average price of a ticket

# %%
df['Fare'].mean()
# Out:
# 32.2042079685746

# %% [markdown]
# 7. Display the plot of Age only for survivers

# %%
total_survive=df.groupby(['Age']).sum().Survived
total_survive.hist()

# %% [markdown]
# 8. Save the content

# %%
df.to_csv(r'output.csv')
