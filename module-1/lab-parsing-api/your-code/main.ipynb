# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# 1. Import libraries.

import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# 2. Define the initial API endpoint URL.
#And headers

url_femme = 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=84&sort=sale'
url_homme = 'https://www.zalando.fr//api/catalog/articles?categories=promo-homme&limit=84&offset=84&sort=sale'

headers = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'}

# %%
# 3. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
response = requests.get(url_femme,  headers=headers) #We get the data
results = response.json() #We transform it on json


flattened_data = json_normalize(results)#We normalize the json obtained

flattened_data1 = json_normalize(flattened_data.articles[0]) #We transform the json into a dataframe with column names
flattened_data1
# Out:
#                   brand_name  \
# 0            Nike Sportswear
# 1            Nike Sportswear
# 2                       ONLY
# 3                   Even&Odd
# 4            Nike Sportswear
# 5            Nike Sportswear
# 6                  Vero Moda
# 7                   New Look
# 8            Nike Sportswear
# 9          Polo Ralph Lauren
# 10           Nike Sportswear
# 11                mint&berry
# 12          Nike Performance
# 13                      Fila
# 14                Missguided
# 15                mint&berry
# 16          adidas Originals
# 17              Carhartt WIP
# 18             Hollister Co.
# 19                   Levi's®
# 20                  Even&Odd
# 21                   PARFOIS
# 22                  New Look
# 23                   TWINTIP
# 24                   TWINTIP
# 25          Glamorous Petite
# 26                   Levi's®
# 27  Dorothy Perkins Wide Fit
# 28              Carhartt WIP
# 29               New Balance
# ..                       ...
# 54                  Pier One
# 55             edc by Esprit
# 56                  New Look
# 57                      RAID
# 58           Nike Sportswear
# 59           Nike Sportswear
# 60                  New Look
# 61                      Fila
# 62                      Puma
# 63                    Pieces
# 64               Tommy Jeans
# 65     Calvin Klein Swimwear
# 66           Dorothy Perkins
# 67                   Tamaris
# 68                      Puma
# 69                  Lost Ink
# 70                      Vila
# 71                mint&berry
# 72           Nike Sportswear
# 73                      ONLY
# 74                      ONLY
# 75                      ONLY
# 76                   Levi's®
# 77                 Noisy May
# 78                 Vero Moda
# 79                Anna Field
# 80                      ONLY
# 81                Missguided
# 82                  New Look
# 83           Nike Sportswear
#
#                                       family_articles  \
# 0   [{'sku': 'NI121A088-Q11', 'url_key': 'nike-spo...
# 1   [{'sku': 'NI111A0FI-Q11', 'url_key': 'nike-spo...
# 2   [{'sku': 'ON321A0YE-Q11', 'url_key': 'only-onl...
# 3   [{'sku': 'EV421C0QE-G12', 'url_key': 'evenando...
# 4   [{'sku': 'NI111A0FJ-A11', 'url_key': 'nike-spo...
# 5   [{'sku': 'NI121J0AG-I11', 'url_key': 'nike-spo...
# 6   [{'sku': 'VE121U06Y-M11', 'url_key': 'vero-mod...
# 7   [{'sku': 'NL011B0CO-O11', 'url_key': 'new-look...
# 8   [{'sku': 'NI111F000-Q11', 'url_key': 'nike-spo...
# 9   [{'sku': 'PO251F00G-Q11', 'url_key': 'polo-ral...
# 10  [{'sku': 'NI111A0D8-A11', 'url_key': 'nike-spo...
# 11  [{'sku': 'M3221E0CT-K11', 'url_key': 'mintandb...
# 12  [{'sku': 'N1241A0NO-Q11', 'url_key': 'nike-per...
# 13  [{'sku': '1FI21J00Z-A11', 'url_key': 'fila-jus...
# 14  [{'sku': 'M0Q21D0BE-Q11', 'url_key': 'missguid...
# 15  [{'sku': 'M3221E0BO-Q11', 'url_key': 'mintandb...
# 16  [{'sku': 'AD115O09Q-C11', 'url_key': 'adidas-o...
# 17  [{'sku': 'C1421D01G-Q11', 'url_key': 'carhartt...
# 18  [{'sku': 'H0421J01K-C11', 'url_key': 'holliste...
# 19  [{'sku': 'LE221E04Q-C11', 'url_key': 'levisr-a...
# 20  [{'sku': 'EV421A079-N11', 'url_key': 'evenando...
# 21  [{'sku': 'P0G11A044-K11', 'url_key': 'parfois-...
# 22  [{'sku': 'NL021S04N-K11', 'url_key': 'new-look...
# 23  [{'sku': 'TW421D0DX-T11', 'url_key': 'twintip-...
# 24  [{'sku': 'TW421A035-O11', 'url_key': 'twintip-...
# 25  [{'sku': 'GLB21E01E-Q11', 'url_key': 'glamorou...
# 26  [{'sku': 'LE221D033-C11', 'url_key': 'levi-s-t...
# 27  [{'sku': 'DOB11B01O-K12', 'url_key': 'dorothy-...
# 28  [{'sku': 'C1421D01O-G11', 'url_key': 'carhartt...
# 29  [{'sku': 'NE211A064-Q11', 'url_key': 'new-bala...
# ..                                                ...
# 54  [{'sku': 'PI911CA13-Q11', 'url_key': 'pier-one...
# 55  [{'sku': 'ED121S03W-K11', 'url_key': 'edc-by-e...
# 56  [{'sku': 'NL011B0CW-G11', 'url_key': 'new-look...
# 57  [{'sku': 'RAD11A05C-E11', 'url_key': 'raid-gri...
# 58  [{'sku': 'NI121D0DS-A11', 'url_key': 'nike-spo...
# 59  [{'sku': 'NI121D0DG-O11', 'url_key': 'nike-spo...
# 60  [{'sku': 'NL011N0A6-E11', 'url_key': 'new-look...
# 61  [{'sku': '1FI21D009-K12', 'url_key': 'fila-all...
# 62  [{'sku': 'PU111A0DP-A11', 'url_key': 'puma-bas...
# 63  [{'sku': 'PE321I067-C11', 'url_key': 'pieces-p...
# 64  [{'sku': 'TOB21D04S-Q11', 'url_key': 'tommy-je...
# 65  [{'sku': 'C1781I00Y-A11', 'url_key': 'calvin-k...
# 66  [{'sku': 'DP521E16I-A11', 'url_key': 'dorothy-...
# 67  [{'sku': 'TA111X07D-Q11', 'url_key': 'tamaris-...
# 68  [{'sku': 'PU121A03A-A11', 'url_key': 'puma-pan...
# 69  [{'sku': 'L0U21I03F-B11', 'url_key': 'lost-ink...
# 70  [{'sku': 'V1021I0TS-G11', 'url_key': 'vila-vis...
# 71  [{'sku': 'M3211CA0M-Q11', 'url_key': 'mintandb...
# 72  [{'sku': 'NI111A0CQ-A12', 'url_key': 'nike-spo...
# 73  [{'sku': 'ON321E1G4-K11', 'url_key': 'only-onl...
# 74  [{'sku': 'ON321E1DH-A11', 'url_key': 'only-onl...
# 75  [{'sku': 'ON321U09B-C12', 'url_key': 'only-onl...
# 76  [{'sku': 'LE221J00U-A11', 'url_key': 'levisr-g...
# 77  [{'sku': 'NM321I0B4-C11', 'url_key': 'noisy-ma...
# 78  [{'sku': 'VE121C1PX-Q11', 'url_key': 'vero-mod...
# 79  [{'sku': 'AN621A03T-Q11', 'url_key': 'anna-fie...
# 80  [{'sku': 'ON321I1F4-Q11', 'url_key': 'only-onl...
# 81  [{'sku': 'M0Q21N04T-C11', 'url_key': 'missguid...
# 82  [{'sku': 'NL021E0U8-M11', 'url_key': 'new-look...
# 83  [{'sku': 'NI121A08J-I11', 'url_key': 'nike-spo...
#
#                                                 flags  is_premium  \
# 0   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 1   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 2   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 3   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 4   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 5   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 6   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 7   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 8   [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 9   [{'key': 'campaign', 'value': '-15% EXTRA', 't...        True
# 10  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 12  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 13  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 14  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 15  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 16  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 17  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 18  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 19  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 20  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 21  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 22  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 23  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 24  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 25  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 26  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 27  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 28  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 29  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# ..                                                ...         ...
# 54  [{'key': 'discountRate', 'value': 'Jusqu’à -60...       False
# 55  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 56  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 57  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 58  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 59  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 60  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 61  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 62  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# 63  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 64  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 65  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 66  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 67  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 68  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 69  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 70  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 71  [{'key': 'discountRate', 'value': '-60%', 'tra...       False
# 72  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 73  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 74  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 75  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 76  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 77  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 78  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 79  [{'key': 'discountRate', 'value': '-20%', 'tra...       False
# 80  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 81  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 82  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 83  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
#
#                                                 media  \
# 0   [{'path': 'NI/12/1A/08/8Q/11/NI121A088-Q11@4.j...
# 1   [{'path': 'NI/11/1A/0F/IQ/11/NI111A0FI-Q11@16....
# 2   [{'path': 'ON/32/1A/0Y/EQ/11/ON321A0YE-Q11@8.j...
# 3   [{'path': 'EV/42/1C/0Q/EG/12/EV421C0QE-G12@4.j...
# 4   [{'path': 'NI/11/1A/0F/JA/11/NI111A0FJ-A11@17....
# 5   [{'path': 'NI/12/1J/0A/GI/11/NI121J0AG-I11@9.j...
# 6   [{'path': 'VE/12/1U/06/YM/11/VE121U06Y-M11@22....
# 7   [{'path': 'NL/01/1B/0C/OO/11/NL011B0CO-O11@11....
# 8   [{'path': 'NI/11/1F/00/0Q/11/NI111F000-Q11@12....
# 9   [{'path': 'PO/25/1F/00/GQ/11/PO251F00G-Q11@11....
# 10  [{'path': 'NI/11/1A/0D/8A/11/NI111A0D8-A11@5.j...
# 11  [{'path': 'M3/22/1E/0C/TK/11/M3221E0CT-K11@11....
# 12  [{'path': 'N1/24/1A/0N/OQ/11/N1241A0NO-Q11@9.1...
# 13  [{'path': '1F/I2/1J/00/ZA/11/1FI21J00Z-A11@9.j...
# 14  [{'path': 'M0/Q2/1D/0B/EQ/11/M0Q21D0BE-Q11@6.1...
# 15  [{'path': 'M3/22/1E/0B/OQ/11/M3221E0BO-Q11@5.j...
# 16  [{'path': 'AD/11/5O/09/QC/11/AD115O09Q-C11@8.1...
# 17  [{'path': 'C1/42/1D/01/GQ/11/C1421D01G-Q11@8.j...
# 18  [{'path': 'H0/42/1J/01/KC/11/H0421J01K-C11@10....
# 19  [{'path': 'LE/22/1E/04/QC/11/LE221E04Q-C11@9.j...
# 20  [{'path': 'EV/42/1A/07/9N/11/EV421A079-N11@22....
# 21  [{'path': 'P0/G1/1A/04/4K/11/P0G11A044-K11@3.j...
# 22  [{'path': 'NL/02/1S/04/NK/11/NL021S04N-K11@4.j...
# 23  [{'path': 'TW/42/1D/0D/XT/11/TW421D0DX-T11@7.j...
# 24  [{'path': 'TW/42/1A/03/5O/11/TW421A035-O11@13....
# 25  [{'path': 'GL/B2/1E/01/EQ/11/GLB21E01E-Q11@4.j...
# 26  [{'path': 'LE/22/1D/03/3C/11/LE221D033-C11@8.j...
# 27  [{'path': 'DO/B1/1B/01/OK/12/DOB11B01O-K12@11....
# 28  [{'path': 'C1/42/1D/01/OG/11/C1421D01O-G11@11....
# 29  [{'path': 'NE/21/1A/06/4Q/11/NE211A064-Q11@9.j...
# ..                                                ...
# 54  [{'path': 'PI/91/1C/A1/3Q/11/PI911CA13-Q11@13....
# 55  [{'path': 'ED/12/1S/03/WK/11/ED121S03W-K11@12....
# 56  [{'path': 'NL/01/1B/0C/WG/11/NL011B0CW-G11@12....
# 57  [{'path': 'RA/D1/1A/05/CE/11/RAD11A05C-E11@10....
# 58  [{'path': 'NI/12/1D/0D/SA/11/NI121D0DS-A11@4.j...
# 59  [{'path': 'NI/12/1D/0D/GO/11/NI121D0DG-O11@9.j...
# 60  [{'path': 'NL/01/1N/0A/6E/11/NL011N0A6-E11@10....
# 61  [{'path': '1F/I2/1D/00/9K/12/1FI21D009-K12@4.j...
# 62  [{'path': 'PU/11/1A/0D/PA/11/PU111A0DP-A11@15....
# 63  [{'path': 'PE/32/1I/06/7C/11/PE321I067-C11@4.j...
# 64  [{'path': 'TO/B2/1D/04/SQ/11/TOB21D04S-Q11@11....
# 65  [{'path': 'C1/78/1I/00/YA/11/C1781I00Y-A11@7.j...
# 66  [{'path': 'DP/52/1E/16/IA/11/DP521E16I-A11@9.j...
# 67  [{'path': 'TA/11/1X/07/DQ/11/TA111X07D-Q11@3.j...
# 68  [{'path': 'PU/12/1A/03/AA/11/PU121A03A-A11@9.j...
# 69  [{'path': 'L0/U2/1I/03/FB/11/L0U21I03F-B11@4.j...
# 70  [{'path': 'V1/02/1I/0T/SG/11/V1021I0TS-G11@8.j...
# 71  [{'path': 'M3/21/1C/A0/MQ/11/M3211CA0M-Q11@13....
# 72  [{'path': 'NI/11/1A/0C/QA/12/NI111A0CQ-A12@7.j...
# 73  [{'path': 'ON/32/1E/1G/4K/11/ON321E1G4-K11@9.j...
# 74  [{'path': 'ON/32/1E/1D/HA/11/ON321E1DH-A11@10....
# 75  [{'path': 'ON/32/1U/09/BC/12/ON321U09B-C12@7.p...
# 76  [{'path': 'LE/22/1J/00/UA/11/LE221J00U-A11@12....
# 77  [{'path': 'NM/32/1I/0B/4C/11/NM321I0B4-C11@4.j...
# 78  [{'path': 'VE/12/1C/1P/XQ/11/VE121C1PX-Q11@21....
# 79  [{'path': 'AN/62/1A/03/TQ/11/AN621A03T-Q11@8.j...
# 80  [{'path': 'ON/32/1I/1F/4Q/11/ON321I1F4-Q11@14....
# 81  [{'path': 'M0/Q2/1N/04/TC/11/M0Q21N04T-C11@27....
# 82  [{'path': 'NL/02/1E/0U/8M/11/NL021E0U8-M11@8.j...
# 83  [{'path': 'NI/12/1A/08/JI/11/NI121A08J-I11@4.j...
#
#                                                  name outfits  \
# 0             RALLY - Pantalon de survêtement - black     NaN
# 1   M2K TEKNO - Baskets basses - black/anthracite/...     NaN
# 2   ONLANNYA HW BELT PANTS TLR - Pantalon classiqu...     NaN
# 3                                   Robe d'été -  red     NaN
# 4   REACT ELEMENT 55  - Baskets basses - white/mid...     NaN
# 5      NSW AIR CREW - Sweatshirt - space purple/white     NaN
# 6                   VMROSA PARKA - Parka - grape leaf     NaN
# 7           REETAH - Escarpins à talons hauts - brown     NaN
# 8                   BENASSI JDI - Mules - black/white     NaN
# 9                 CHAIN WALLET - Portefeuille - black     NaN
# 10  AF1 JESTER XX - Baskets basses - white/laser f...     NaN
# 11                                   Chemisier - navy     NaN
# 12  REVOLUTION 4 - Chaussures de running neutres -...     NaN
# 13  JUSTYNA BUTTONED CREW - Sweatshirt - bright wh...     NaN
# 14  SHEARED BANDEAU 2 PACK  - Débardeur - black/mu...     NaN
# 15                                     Blouse - black     NaN
# 16  NITE JOGGER - Baskets basses - grey two/solid ...     NaN
# 17             SCRIPT - T-shirt imprimé - black/white     NaN
# 18  LONG SLEEVE LOGO HOODIE TEE - T-shirt à manche...     NaN
# 19                 ADDISON - Chemisier - side stepper     NaN
# 20                                 Jean flare - khaki     NaN
# 21                                  Tongs - dark navy     NaN
# 22        HOTPANT APPLE - Short en jean - bright blue     NaN
# 23          T-shirt à manches longues - multicoloured     NaN
# 24                         Pantalon classique - brown     NaN
# 25                       FLORAL WRAP - Blouse - black     NaN
# 26               THE PERFECT - T-shirt imprimé - grey     NaN
# 27  WIDE FIT CLOVERS - Talons hauts à bout ouvert ...     NaN
# 28             KNOWLEDGE - T-shirt imprimé - cardinal     NaN
# 29                   WX608 - Baskets basses - schwarz     NaN
# ..                                                ...     ...
# 54                                    Derbies - black     NaN
# 55                                PLAY - Short - navy     NaN
# 56   SERENITY - Escarpins à talons hauts - bright red     NaN
# 57            GRIER - Sandales à talons hauts - green     NaN
# 58  T-shirt à manches longues - white/black/desert...     NaN
# 59               T-shirt imprimé - desert ochre/black     NaN
# 60                 THRIVING - Boots à talons - yellow     NaN
# 61  ALLISON TEE - T-shirt imprimé - black iris/tru...     NaN
# 62                             Baskets basses - white     NaN
# 63                 PCDELLY - Pullover - whitecap gray     NaN
# 64    SOFT V NECK TEE - T-shirt basique - tommy black     NaN
# 65  INTENSE POWER CLASSIC STRIPE - Bas de bikini -...     NaN
# 66       SQUARE NECK TIE SLEEVE  - Blouse - off white     NaN
# 67                            Bottes de neige - black     NaN
# 68            PANTS - Pantalon de survêtement - white     NaN
# 69     FRONT CUT OUT BARDOT JUMPER - Pullover - beige     NaN
# 70         VISOLDANA LAYER - Pullover - cherry tomato     NaN
# 71                             Boots à talons - black     NaN
# 72  AIR MAX 270 - Baskets basses - sail/pumice/spa...     NaN
# 73               ONLSEVANNA TANK - Blouse - night sky     NaN
# 74  ONLJULITS L/S JAQUARD DOTS DNM SHIR - Chemisie...     NaN
# 75       ONLSEDONA  - Manteau court - oatmeal/melange     NaN
# 76      GRAPHIC SPORT - Sweat à capuche - marshmallow     NaN
# 77  NMPATRICE HIGH NECK - Pullover - dark grey mel...     NaN
# 78            VMSASHA BALI DRESS - Robe d'été - black     NaN
# 79                         Pantalon classique - black     NaN
# 80                         ONLMAGA - Pullover - black     NaN
# 81              VICE STONEWASH - Jeans Skinny - stone     NaN
# 82            CROSS BACK CAMI - Débardeur - mid green     NaN
# 83  AIR PANT - Pantalon de survêtement - night mar...     NaN
#
#     price.has_different_original_prices  price.has_different_prices  \
# 0                                 False                        True
# 1                                 False                        True
# 2                                 False                       False
# 3                                 False                       False
# 4                                 False                        True
# 5                                 False                        True
# 6                                 False                       False
# 7                                 False                       False
# 8                                 False                        True
# 9                                 False                       False
# 10                                False                       False
# 11                                False                       False
# 12                                False                        True
# 13                                False                       False
# 14                                False                       False
# 15                                False                       False
# 16                                False                        True
# 17                                False                       False
# 18                                False                       False
# 19                                False                        True
# 20                                False                       False
# 21                                False                       False
# 22                                False                       False
# 23                                False                       False
# 24                                False                       False
# 25                                False                       False
# 26                                False                       False
# 27                                False                       False
# 28                                False                       False
# 29                                False                       False
# ..                                  ...                         ...
# 54                                False                        True
# 55                                False                        True
# 56                                False                       False
# 57                                False                       False
# 58                                False                        True
# 59                                False                        True
# 60                                False                       False
# 61                                False                       False
# 62                                False                       False
# 63                                False                        True
# 64                                False                       False
# 65                                False                       False
# 66                                False                       False
# 67                                False                       False
# 68                                False                       False
# 69                                False                       False
# 70                                False                       False
# 71                                False                       False
# 72                                False                        True
# 73                                False                       False
# 74                                False                       False
# 75                                False                        True
# 76                                False                       False
# 77                                False                       False
# 78                                False                       False
# 79                                False                       False
# 80                                False                       False
# 81                                False                       False
# 82                                False                       False
# 83                                False                       False
#
#     price.has_different_promotional_prices  \
# 0                                     True
# 1                                     True
# 2                                    False
# 3                                    False
# 4                                     True
# 5                                     True
# 6                                    False
# 7                                    False
# 8                                     True
# 9                                    False
# 10                                   False
# 11                                   False
# 12                                    True
# 13                                   False
# 14                                   False
# 15                                   False
# 16                                    True
# 17                                   False
# 18                                   False
# 19                                    True
# 20                                   False
# 21                                   False
# 22                                   False
# 23                                   False
# 24                                   False
# 25                                   False
# 26                                   False
# 27                                   False
# 28                                   False
# 29                                   False
# ..                                     ...
# 54                                    True
# 55                                    True
# 56                                   False
# 57                                   False
# 58                                    True
# 59                                    True
# 60                                   False
# 61                                   False
# 62                                   False
# 63                                    True
# 64                                   False
# 65                                   False
# 66                                   False
# 67                                   False
# 68                                   False
# 69                                   False
# 70                                   False
# 71                                   False
# 72                                    True
# 73                                   False
# 74                                   False
# 75                                    True
# 76                                   False
# 77                                   False
# 78                                   False
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only price.original  \
# 0                                       False        44,95 €
# 1                                       False       109,95 €
# 2                                       False        39,95 €
# 3                                       False        24,99 €
# 4                                       False       129,95 €
# 5                                       False        59,95 €
# 6                                       False        49,99 €
# 7                                       False        25,99 €
# 8                                       False        27,95 €
# 9                                       False       229,95 €
# 10                                      False       109,95 €
# 11                                      False        39,99 €
# 12                                      False        49,95 €
# 13                                      False        89,95 €
# 14                                      False        19,99 €
# 15                                      False        39,99 €
# 16                                      False       129,95 €
# 17                                      False        28,95 €
# 18                                      False        31,95 €
# 19                                      False        64,95 €
# 20                                      False        34,95 €
# 21                                      False        19,95 €
# 22                                      False        21,95 €
# 23                                      False        19,95 €
# 24                                      False        26,95 €
# 25                                      False        36,99 €
# 26                                      False        24,95 €
# 27                                      False        25,95 €
# 28                                      False        34,95 €
# 29                                      False        84,95 €
# ..                                        ...            ...
# 54                                      False        59,95 €
# 55                                      False        39,99 €
# 56                                      False        25,99 €
# 57                                      False        34,95 €
# 58                                      False        39,95 €
# 59                                      False        34,95 €
# 60                                      False        25,99 €
# 61                                      False        34,95 €
# 62                                      False        90,00 €
# 63                                      False        39,99 €
# 64                                      False        29,95 €
# 65                                      False        43,95 €
# 66                                      False        35,95 €
# 67                                      False        99,95 €
# 68                                      False        59,95 €
# 69                                      False        32,99 €
# 70                                      False        29,99 €
# 71                                      False        69,99 €
# 72                                      False       149,95 €
# 73                                      False        24,95 €
# 74                                      False        29,99 €
# 75                                      False        59,99 €
# 76                                      False        69,95 €
# 77                                      False        34,99 €
# 78                                      False        26,99 €
# 79                                      False        34,99 €
# 80                                      False        26,99 €
# 81                                      False        27,99 €
# 82                                      False        16,95 €
# 83                                      False        54,95 €
#
#    price.promotional product_group  \
# 0            31,46 €      clothing
# 1            59,95 €          shoe
# 2            20,00 €      clothing
# 3            16,24 €      clothing
# 4           104,00 €          shoe
# 5            17,95 €      clothing
# 6            15,00 €      clothing
# 7             7,80 €          shoe
# 8            19,56 €          shoe
# 9            68,95 €   accessoires
# 10           87,95 €          shoe
# 11           12,00 €      clothing
# 12           35,00 €          shoe
# 13           26,95 €      clothing
# 14           15,00 €      clothing
# 15           12,00 €      clothing
# 16           78,00 €          shoe
# 17           23,16 €      clothing
# 18            9,60 €      clothing
# 19           23,00 €      clothing
# 20           10,50 €      clothing
# 21            6,00 €          shoe
# 22           17,55 €      clothing
# 23            8,00 €      clothing
# 24           10,80 €      clothing
# 25           11,00 €      clothing
# 26           17,46 €      clothing
# 27           20,76 €          shoe
# 28           21,00 €      clothing
# 29           51,00 €          shoe
# ..               ...           ...
# 54           24,00 €          shoe
# 55           16,00 €      clothing
# 56           13,00 €          shoe
# 57           10,50 €          shoe
# 58           20,00 €      clothing
# 59           21,00 €      clothing
# 60            7,80 €          shoe
# 61           29,71 €      clothing
# 62           63,00 €          shoe
# 63           12,00 €      clothing
# 64           21,00 €      clothing
# 65           32,95 €    beach_wear
# 66           10,79 €      clothing
# 67           29,95 €          shoe
# 68           30,00 €      clothing
# 69           13,20 €      clothing
# 70            9,00 €      clothing
# 71           28,00 €          shoe
# 72          105,00 €          shoe
# 73            7,49 €      clothing
# 74            9,00 €      clothing
# 75           17,95 €      clothing
# 76           49,00 €      clothing
# 77           10,50 €      clothing
# 78           21,60 €      clothing
# 79           28,00 €      clothing
# 80            8,00 €      clothing
# 81           16,80 €      clothing
# 82            7,65 €      clothing
# 83           38,46 €      clothing
#
#                                                 sizes            sku  \
# 0                                   [XS, S, M, L, XL]  NI121A088-Q11
# 1   [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5,...  NI111A0FI-Q11
# 2                                [36, 38, 40, 42, 44]  ON321A0YE-Q11
# 3                                    [38, 40, 42, 44]  EV421C0QE-G12
# 4   [36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5, 41, 4...  NI111A0FJ-A11
# 5                                   [XS, S, M, L, XL]  NI121J0AG-I11
# 6                                   [XS, S, M, L, XL]  VE121U06Y-M11
# 7                                [37, 38, 39, 40, 41]  NL011B0CO-O11
# 8                  [36.5, 38, 39, 40.5, 42, 43, 44.5]  NI111F000-Q11
# 9                                          [One Size]  PO251F00G-Q11
# 10  [36.5, 37.5, 38, 38.5, 39, 40, 40.5, 41, 42, 4...  NI111A0D8-A11
# 11                               [34, 36, 38, 40, 42]  M3221E0CT-K11
# 12  [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5,...  N1241A0NO-Q11
# 13                                      [XS, S, M, L]  1FI21J00Z-A11
# 14                               [34, 36, 38, 40, 42]  M0Q21D0BE-Q11
# 15                           [34, 36, 38, 40, 42, 44]  M3221E0BO-Q11
# 16  [36, 38, 40, 42, 44, 46, 36 2/3, 37 1/3, 38 2/...  AD115O09Q-C11
# 17                                          [S, M, L]  C1421D01G-Q11
# 18                                      [XS, S, M, L]  H0421J01K-C11
# 19                                      [XS, S, M, L]  LE221E04Q-C11
# 20                               [36, 38, 40, 42, 44]  EV421A079-N11
# 21                               [36, 37, 38, 39, 40]  P0G11A044-K11
# 22                               [34, 36, 42, 44, 46]  NL021S04N-K11
# 23                                  [XS, S, M, L, XL]  TW421D0DX-T11
# 24                               [36, 38, 40, 42, 44]  TW421A035-O11
# 25                               [34, 36, 38, 40, 42]  GLB21E01E-Q11
# 26                                      [XS, S, M, L]  LE221D033-C11
# 27                               [37, 38, 39, 40, 42]  DOB11B01O-K12
# 28                                         [XS, M, L]  C1421D01O-G11
# 29             [37, 37.5, 38, 39, 40, 40.5, 41, 41.5]  NE211A064-Q11
# ..                                                ...            ...
# 54                           [37, 38, 39, 40, 41, 42]  PI911CA13-Q11
# 55                       [34, 36, 38, 40, 42, 44, 46]  ED121S03W-K11
# 56                               [38, 39, 40, 41, 42]  NL011B0CW-G11
# 57                               [36, 37, 38, 39, 41]  RAD11A05C-E11
# 58                             [XS, S, M, L, XL, XXL]  NI121D0DS-A11
# 59                                      [XS, S, M, L]  NI121D0DG-O11
# 60                       [36, 37, 38, 39, 40, 41, 42]  NL011N0A6-E11
# 61                                  [XS, S, M, L, XL]  1FI21D009-K12
# 62     [36, 37, 37.5, 38, 38.5, 39, 40, 40.5, 41, 42]  PU111A0DP-A11
# 63                                  [XS, S, M, L, XL]  PE321I067-C11
# 64                             [XXS, XS, S, M, L, XL]  TOB21D04S-Q11
# 65                                         [XS, S, M]  C1781I00Y-A11
# 66                               [34, 40, 42, 44, 46]  DP521E16I-A11
# 67                               [37, 38, 39, 40, 41]  TA111X07D-Q11
# 68                                      [S, M, L, XL]  PU121A03A-A11
# 69                               [34, 36, 38, 40, 42]  L0U21I03F-B11
# 70                                  [XS, S, M, L, XL]  V1021I0TS-G11
# 71                               [36, 37, 38, 40, 42]  M3211CA0M-Q11
# 72  [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40, 41, 4...  NI111A0CQ-A12
# 73                               [36, 38, 40, 42, 44]  ON321E1G4-K11
# 74                               [36, 38, 40, 42, 44]  ON321E1DH-A11
# 75                                      [XS, S, M, L]  ON321U09B-C12
# 76                                 [XXS, XS, S, M, L]  LE221J00U-A11
# 77                               [36, 38, 40, 42, 44]  NM321I0B4-C11
# 78                                  [XS, S, M, L, XL]  VE121C1PX-Q11
# 79                       [34, 36, 38, 40, 42, 44, 46]  AN621A03T-Q11
# 80                                      [S, M, L, XL]  ON321I1F4-Q11
# 81                               [34, 36, 38, 40, 42]  M0Q21N04T-C11
# 82                       [34, 36, 38, 40, 42, 44, 46]  NL021E0U8-M11
# 83                                  [XS, S, M, L, XL]  NI121A08J-I11
#
#                                               url_key
# 0   nike-sportswear-rally-pantalon-de-survetement-...
# 1   nike-sportswear-m2k-tekno-baskets-basses-ni111...
# 2   only-onlannya-hw-belt-pants-tlr-pantalon-class...
# 3              evenandodd-robe-dete-red-ev421c0qe-g12
# 4   nike-sportswear-react-55-premium-baskets-basse...
# 5   nike-sportswear-air-crew-sweatshirt-ni121j0ag-i11
# 6          vero-moda-vmrosa-parka-parka-ve121u06y-m11
# 7       new-look-reetah-escarpins-brown-nl011b0co-o11
# 8   nike-sportswear-sandales-de-bain-black-white-n...
# 9   polo-ralph-lauren-chain-wallet-portefeuille-bl...
# 10  nike-sportswear-af1-jester-xx-baskets-basses-n...
# 11          mintandberry-chemisier-navy-m3221e0ct-k11
# 12  nike-performance-revolution-4-eu-chaussures-de...
# 13  fila-justyna-buttoned-crew-sweatshirt-bright-w...
# 14  missguided-sheared-bandeau-2-pack-debardeur-bl...
# 15            mintandberry-blouse-black-m3221e0bo-q11
# 16  adidas-originals-nite-jogger-baskets-basses-gr...
# 17  carhartt-wip-script-t-shirt-imprime-c1421d01g-q11
# 18  hollister-co-long-sleeve-logo-hoodie-tee-t-shi...
# 19  levisr-addison-chemisier-side-stepper-le221e04...
# 20          evenandodd-jean-flare-khaki-ev421a079-n11
# 21              parfois-tongs-dark-navy-p0g11a044-k11
# 22  new-look-hotpant-apple-short-en-jean-bright-bl...
# 23  twintip-t-shirt-a-manches-longues-multicoloure...
# 24     twintip-pantalon-classique-brown-tw421a035-o11
# 25  glamorous-petite-floral-wrap-blouse-black-glb2...
# 26   levi-s-the-perfect-t-shirt-imprime-le221d033-c11
# 27  dorothy-perkins-wide-fit-wide-fit-clovers-esca...
# 28  carhartt-wip-knowledge-t-shirt-imprime-c1421d0...
# 29     new-balance-wx608-baskets-basses-ne211a064-q11
# ..                                                ...
# 54               pier-one-derbies-black-pi911ca13-q11
# 55             edc-by-esprit-play-short-ed121s03w-k11
# 56  new-look-serenity-escarpins-bright-red-nl011b0...
# 57            raid-grier-sandales-green-rad11a05c-e11
# 58  nike-sportswear-t-shirt-a-manches-longues-whit...
# 59  nike-sportswear-t-shirt-imprime-desert-ochrebl...
# 60  new-look-thriving-boots-a-talons-yellow-nl011n...
# 61     fila-allison-tee-t-shirt-imprime-1fi21d009-k12
# 62            puma-baskets-basses-white-pu111a0dp-a11
# 63        pieces-pullover-whitecap-gray-pe321i067-c11
# 64  tommy-jeans-soft-v-neck-tee-t-shirt-imprime-to...
# 65  calvin-klein-swimwear-intense-power-classic-st...
# 66  dorothy-perkins-square-neck-tie-sleeve-blouse-...
# 67        tamaris-bottes-de-neige-black-ta111x07d-q11
# 68   puma-pants-pantalon-de-survetement-pu121a03a-a11
# 69  lost-ink-front-cut-out-bardot-jumper-pullover-...
# 70  vila-visoldana-layer-pullover-cherry-tomato-v1...
# 71    mintandberry-boots-a-talons-black-m3211ca0m-q11
# 72  nike-sportswear-air-max-270-baskets-basses-ni1...
# 73       only-onlsevanna-tank-debardeur-on321e1g4-k11
# 74  only-onljulits-ls-jaquard-dots-dnm-shir-chemis...
# 75  only-onlsedona-link-spring-coat-manteau-classi...
# 76      levisr-graphic-sport-sweatshirt-le221j00u-a11
# 77  noisy-may-nmpatrice-high-neck-pullover-nm321i0...
# 78  vero-moda-vmsasha-bali-short-dress-robe-dete-b...
# 79  anna-field-pantalon-classique-black-an621a03t-q11
# 80          only-onlmaga-pullover-black-on321i1f4-q11
# 81  missguided-vice-stonewash-jeans-skinny-stone-m...
# 82   new-look-cross-back-cami-debardeur-nl021e0u8-m11
# 83  nike-sportswear-air-pant-pantalon-de-surveteme...
#
# [84 rows x 17 columns]

# %%
# 4. Find out the total page count in the 1st page data.
total_pages=results['pagination']['page_count']

# %%
# 5. Use a FOR loop to make requests for the additional pages from 2 to page count. 
# Append the data of each additional page to the flatterned data object.

df=pd.DataFrame()
for i in range(2):
    k=84*i
    if i % 100==0:
        print(i)
    url='https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset='+str(k)+'&sort=sale'
    response = requests.get(url, headers=headers)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

df
# Out:
# 0
#                           brand_name  \
# sku
# CO411A0RW-Q11               Converse
# HA111D00E-J15              Havaianas
# HA111Z00Q-C11              Havaianas
# NI111A0E6-C11        Nike Sportswear
# NI121A05J-C11        Nike Sportswear
# PU111A09B-K11                   Puma
# NI111A0EU-K11        Nike Sportswear
# OY121T00M-A11                  OYSHO
# PO221D04T-G11      Polo Ralph Lauren
# PU111S05F-Q13                   Puma
# VA211S03A-Q11                   Vans
# AD121A096-C11       adidas Originals
# CO411S099-A11               Converse
# NI111A0D2-B11        Nike Sportswear
# PU111A0EB-C11                   Puma
# HA111A00O-F11              Havaianas
# HA111A00I-J11              Havaianas
# HA111B00K-F11              Havaianas
# LE221D033-A13                Levi's®
# LA221D03E-K11                Lacoste
# VE121G0QB-M11              Vero Moda
# 1FI11A01K-A11                   Fila
# LA211A09O-A11                Lacoste
# NI121A08A-G11        Nike Sportswear
# NI121G03Q-E11        Nike Sportswear
# NM321B055-K11              Noisy May
# NI121D0E2-A11        Nike Sportswear
# VE121C1G7-K11              Vero Moda
# LA211S03Z-A11                Lacoste
# EV421E04A-I11               Even&Odd
# ...                              ...
# ED121S03W-K11          edc by Esprit
# NL011B0CW-G11               New Look
# RAD11A05C-E11                   RAID
# NI121D0DS-A11        Nike Sportswear
# NI121D0DG-O11        Nike Sportswear
# NL011N0A6-E11               New Look
# 1FI21D009-K12                   Fila
# PU111A0DP-A11                   Puma
# PE321I067-C11                 Pieces
# TOB21D04S-Q11            Tommy Jeans
# C1781I00Y-A11  Calvin Klein Swimwear
# DP521E16I-A11        Dorothy Perkins
# TA111X07D-Q11                Tamaris
# PU121A03A-A11                   Puma
# L0U21I03F-B11               Lost Ink
# V1021I0TS-G11                   Vila
# M3211CA0M-Q11             mint&berry
# NI111A0CQ-A12        Nike Sportswear
# ON321E1G4-K11                   ONLY
# ON321E1DH-A11                   ONLY
# ON321U09B-C12                   ONLY
# LE221J00U-A11                Levi's®
# NM321I0B4-C11              Noisy May
# VE121C1PX-Q11              Vero Moda
# AN621A03T-Q11             Anna Field
# ON321I1F4-Q11                   ONLY
# M0Q21N04T-C11             Missguided
# NL021E0U8-M11               New Look
# NI121A08J-I11        Nike Sportswear
# SU221D1IN-C11               Superdry
#
#                                                  family_articles  \
# sku
# CO411A0RW-Q11  [{'sku': 'CO411A0RW-Q11', 'url_key': 'converse...
# HA111D00E-J15  [{'sku': 'HA111D00E-J15', 'url_key': 'havaiana...
# HA111Z00Q-C11  [{'sku': 'HA111Z00Q-C11', 'url_key': 'havaiana...
# NI111A0E6-C11  [{'sku': 'NI111A0E6-C11', 'url_key': 'nike-spo...
# NI121A05J-C11  [{'sku': 'NI121A05J-C11', 'url_key': 'nike-spo...
# PU111A09B-K11  [{'sku': 'PU111A09B-K11', 'url_key': 'puma-bow...
# NI111A0EU-K11  [{'sku': 'NI111A0EU-K11', 'url_key': 'nike-spo...
# OY121T00M-A11  [{'sku': 'OY121T00M-A11', 'url_key': 'oysho-co...
# PO221D04T-G11  [{'sku': 'PO221D04T-G11', 'url_key': 'polo-ral...
# PU111S05F-Q13  [{'sku': 'PU111S05F-Q13', 'url_key': 'puma-vik...
# VA211S03A-Q11  [{'sku': 'VA211S03A-Q11', 'url_key': 'vans-bas...
# AD121A096-C11  [{'sku': 'AD121A096-C11', 'url_key': 'adidas-o...
# CO411S099-A11  [{'sku': 'CO411S099-A11', 'url_key': 'converse...
# NI111A0D2-B11  [{'sku': 'NI111A0D2-B11', 'url_key': 'nike-spo...
# PU111A0EB-C11  [{'sku': 'PU111A0EB-C11', 'url_key': 'puma-vik...
# HA111A00O-F11  [{'sku': 'HA111A00O-F11', 'url_key': 'havaiana...
# HA111A00I-J11  [{'sku': 'HA111A00I-J11', 'url_key': 'havaiana...
# HA111B00K-F11  [{'sku': 'HA111B00K-F11', 'url_key': 'havaiana...
# LE221D033-A13  [{'sku': 'LE221D033-A13', 'url_key': 'levi-s-t...
# LA221D03E-K11  [{'sku': 'LA221D03E-K11', 'url_key': 'lacoste-...
# VE121G0QB-M11  [{'sku': 'VE121G0QB-M11', 'url_key': 'vero-mod...
# 1FI11A01K-A11  [{'sku': '1FI11A01K-A11', 'url_key': 'fila-dis...
# LA211A09O-A11  [{'sku': 'LA211A09O-A11', 'url_key': 'lacoste-...
# NI121A08A-G11  [{'sku': 'NI121A08A-G11', 'url_key': 'nike-spo...
# NI121G03Q-E11  [{'sku': 'NI121G03Q-E11', 'url_key': 'nike-spo...
# NM321B055-K11  [{'sku': 'NM321B055-K11', 'url_key': 'noisy-ma...
# NI121D0E2-A11  [{'sku': 'NI121D0E2-A11', 'url_key': 'nike-spo...
# VE121C1G7-K11  [{'sku': 'VE121C1G7-K11', 'url_key': 'vero-mod...
# LA211S03Z-A11  [{'sku': 'LA211S03Z-A11', 'url_key': 'lacoste-...
# EV421E04A-I11  [{'sku': 'EV421E04A-I11', 'url_key': 'evenando...
# ...                                                          ...
# ED121S03W-K11  [{'sku': 'ED121S03W-K11', 'url_key': 'edc-by-e...
# NL011B0CW-G11  [{'sku': 'NL011B0CW-G11', 'url_key': 'new-look...
# RAD11A05C-E11  [{'sku': 'RAD11A05C-E11', 'url_key': 'raid-gri...
# NI121D0DS-A11  [{'sku': 'NI121D0DS-A11', 'url_key': 'nike-spo...
# NI121D0DG-O11  [{'sku': 'NI121D0DG-O11', 'url_key': 'nike-spo...
# NL011N0A6-E11  [{'sku': 'NL011N0A6-E11', 'url_key': 'new-look...
# 1FI21D009-K12  [{'sku': '1FI21D009-K12', 'url_key': 'fila-all...
# PU111A0DP-A11  [{'sku': 'PU111A0DP-A11', 'url_key': 'puma-bas...
# PE321I067-C11  [{'sku': 'PE321I067-C11', 'url_key': 'pieces-p...
# TOB21D04S-Q11  [{'sku': 'TOB21D04S-Q11', 'url_key': 'tommy-je...
# C1781I00Y-A11  [{'sku': 'C1781I00Y-A11', 'url_key': 'calvin-k...
# DP521E16I-A11  [{'sku': 'DP521E16I-A11', 'url_key': 'dorothy-...
# TA111X07D-Q11  [{'sku': 'TA111X07D-Q11', 'url_key': 'tamaris-...
# PU121A03A-A11  [{'sku': 'PU121A03A-A11', 'url_key': 'puma-pan...
# L0U21I03F-B11  [{'sku': 'L0U21I03F-B11', 'url_key': 'lost-ink...
# V1021I0TS-G11  [{'sku': 'V1021I0TS-G11', 'url_key': 'vila-vis...
# M3211CA0M-Q11  [{'sku': 'M3211CA0M-Q11', 'url_key': 'mintandb...
# NI111A0CQ-A12  [{'sku': 'NI111A0CQ-A12', 'url_key': 'nike-spo...
# ON321E1G4-K11  [{'sku': 'ON321E1G4-K11', 'url_key': 'only-onl...
# ON321E1DH-A11  [{'sku': 'ON321E1DH-A11', 'url_key': 'only-onl...
# ON321U09B-C12  [{'sku': 'ON321U09B-C12', 'url_key': 'only-onl...
# LE221J00U-A11  [{'sku': 'LE221J00U-A11', 'url_key': 'levisr-g...
# NM321I0B4-C11  [{'sku': 'NM321I0B4-C11', 'url_key': 'noisy-ma...
# VE121C1PX-Q11  [{'sku': 'VE121C1PX-Q11', 'url_key': 'vero-mod...
# AN621A03T-Q11  [{'sku': 'AN621A03T-Q11', 'url_key': 'anna-fie...
# ON321I1F4-Q11  [{'sku': 'ON321I1F4-Q11', 'url_key': 'only-onl...
# M0Q21N04T-C11  [{'sku': 'M0Q21N04T-C11', 'url_key': 'missguid...
# NL021E0U8-M11  [{'sku': 'NL021E0U8-M11', 'url_key': 'new-look...
# NI121A08J-I11  [{'sku': 'NI121A08J-I11', 'url_key': 'nike-spo...
# SU221D1IN-C11  [{'sku': 'SU221D1IN-C11', 'url_key': 'superdry...
#
#                                                            flags  is_premium  \
# sku
# CO411A0RW-Q11  [{'key': 'sponsored', 'value': 'Sponsorisé', '...       False
# HA111D00E-J15  [{'key': 'sponsored', 'value': 'Sponsorisé', '...       False
# HA111Z00Q-C11  [{'key': 'sponsored', 'value': 'Sponsorisé', '...       False
# NI111A0E6-C11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# NI121A05J-C11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# PU111A09B-K11  [{'key': 'discountRate', 'value': '-81%', 'tra...       False
# NI111A0EU-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# OY121T00M-A11  [{'key': 'discountRate', 'value': '-38%', 'tra...       False
# PO221D04T-G11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...        True
# PU111S05F-Q13  [{'key': 'discountRate', 'value': '-62%', 'tra...       False
# VA211S03A-Q11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# AD121A096-C11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# CO411S099-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# NI111A0D2-B11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# PU111A0EB-C11  [{'key': 'discountRate', 'value': '-58%', 'tra...       False
# HA111A00O-F11  [{'key': 'sponsored', 'value': 'Sponsorisé', '...       False
# HA111A00I-J11  [{'key': 'sponsored', 'value': 'Sponsorisé', '...       False
# HA111B00K-F11  [{'key': 'sponsored', 'value': 'Sponsorisé', '...       False
# LE221D033-A13  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# LA221D03E-K11  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# VE121G0QB-M11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 1FI11A01K-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# LA211A09O-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# NI121A08A-G11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# NI121G03Q-E11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# NM321B055-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# NI121D0E2-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# VE121C1G7-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# LA211S03Z-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# EV421E04A-I11  [{'key': 'discountRate', 'value': '-70%', 'tra...       False
# ...                                                          ...         ...
# ED121S03W-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# NL011B0CW-G11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# RAD11A05C-E11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# NI121D0DS-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# NI121D0DG-O11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# NL011N0A6-E11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# 1FI21D009-K12  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# PU111A0DP-A11  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# PE321I067-C11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# TOB21D04S-Q11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# C1781I00Y-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# DP521E16I-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# TA111X07D-Q11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# PU121A03A-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# L0U21I03F-B11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# V1021I0TS-G11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# M3211CA0M-Q11  [{'key': 'discountRate', 'value': '-60%', 'tra...       False
# NI111A0CQ-A12  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# ON321E1G4-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# ON321E1DH-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# ON321U09B-C12  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# LE221J00U-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# NM321I0B4-C11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# VE121C1PX-Q11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# AN621A03T-Q11  [{'key': 'discountRate', 'value': '-20%', 'tra...       False
# ON321I1F4-Q11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# M0Q21N04T-C11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# NL021E0U8-M11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# NI121A08J-I11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
# SU221D1IN-C11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...       False
#
#                                                            media  \
# sku
# CO411A0RW-Q11  [{'path': 'CO/41/1A/0R/WQ/11/CO411A0RW-Q11@13....
# HA111D00E-J15  [{'path': 'HA/11/1D/00/EJ/15/HA111D00E-J15@12....
# HA111Z00Q-C11  [{'path': 'HA/11/1Z/00/QC/11/HA111Z00Q-C11@13....
# NI111A0E6-C11  [{'path': 'NI/11/1A/0E/6C/11/NI111A0E6-C11@13....
# NI121A05J-C11  [{'path': 'NI/12/1A/05/JC/11/NI121A05J-C11@8.1...
# PU111A09B-K11  [{'path': 'PU/11/1A/09/BK/11/PU111A09B-K11@13....
# NI111A0EU-K11  [{'path': 'NI/11/1A/0E/UK/11/NI111A0EU-K11@13....
# OY121T00M-A11  [{'path': 'OY/12/1T/00/MA/11/OY121T00M-A11@8.2...
# PO221D04T-G11  [{'path': 'PO/22/1D/04/TG/11/PO221D04T-G11@6.j...
# PU111S05F-Q13  [{'path': 'PU/11/1S/05/FQ/13/PU111S05F-Q13@2.1...
# VA211S03A-Q11  [{'path': 'VA/21/1S/03/AQ/11/VA211S03A-Q11@13....
# AD121A096-C11  [{'path': 'AD/12/1A/09/6C/11/AD121A096-C11@8.j...
# CO411S099-A11  [{'path': 'CO/41/1S/09/9A/11/CO411S099-A11@12....
# NI111A0D2-B11  [{'path': 'NI/11/1A/0D/2B/11/NI111A0D2-B11@5.j...
# PU111A0EB-C11  [{'path': 'PU/11/1A/0E/BC/11/PU111A0EB-C11@2.1...
# HA111A00O-F11  [{'path': 'HA/11/1A/00/OF/11/HA111A00O-F11@11....
# HA111A00I-J11  [{'path': 'HA/11/1A/00/IJ/11/HA111A00I-J11@13....
# HA111B00K-F11  [{'path': 'HA/11/1B/00/KF/11/HA111B00K-F11@11....
# LE221D033-A13  [{'path': 'LE/22/1D/03/3A/13/LE221D033-A13@8.j...
# LA221D03E-K11  [{'path': 'LA/22/1D/03/EK/11/LA221D03E-K11@8.j...
# VE121G0QB-M11  [{'path': 'VE/12/1G/0Q/BM/11/VE121G0QB-M11@12....
# 1FI11A01K-A11  [{'path': '1F/I1/1A/01/KA/11/1FI11A01K-A11@10....
# LA211A09O-A11  [{'path': 'LA/21/1A/09/OA/11/LA211A09O-A11@13....
# NI121A08A-G11  [{'path': 'NI/12/1A/08/AG/11/NI121A08A-G11@4.j...
# NI121G03Q-E11  [{'path': 'NI/12/1G/03/QE/11/NI121G03Q-E11@9.j...
# NM321B055-K11  [{'path': 'NM/32/1B/05/5K/11/NM321B055-K11@11....
# NI121D0E2-A11  [{'path': 'NI/12/1D/0E/2A/11/NI121D0E2-A11@4.j...
# VE121C1G7-K11  [{'path': 'VE/12/1C/1G/7K/11/VE121C1G7-K11@7.j...
# LA211S03Z-A11  [{'path': 'LA/21/1S/03/ZA/11/LA211S03Z-A11@12....
# EV421E04A-I11  [{'path': 'EV/42/1E/04/AI/11/EV421E04A-I11@15....
# ...                                                          ...
# ED121S03W-K11  [{'path': 'ED/12/1S/03/WK/11/ED121S03W-K11@12....
# NL011B0CW-G11  [{'path': 'NL/01/1B/0C/WG/11/NL011B0CW-G11@12....
# RAD11A05C-E11  [{'path': 'RA/D1/1A/05/CE/11/RAD11A05C-E11@10....
# NI121D0DS-A11  [{'path': 'NI/12/1D/0D/SA/11/NI121D0DS-A11@4.j...
# NI121D0DG-O11  [{'path': 'NI/12/1D/0D/GO/11/NI121D0DG-O11@9.j...
# NL011N0A6-E11  [{'path': 'NL/01/1N/0A/6E/11/NL011N0A6-E11@10....
# 1FI21D009-K12  [{'path': '1F/I2/1D/00/9K/12/1FI21D009-K12@4.j...
# PU111A0DP-A11  [{'path': 'PU/11/1A/0D/PA/11/PU111A0DP-A11@15....
# PE321I067-C11  [{'path': 'PE/32/1I/06/7C/11/PE321I067-C11@4.j...
# TOB21D04S-Q11  [{'path': 'TO/B2/1D/04/SQ/11/TOB21D04S-Q11@11....
# C1781I00Y-A11  [{'path': 'C1/78/1I/00/YA/11/C1781I00Y-A11@7.j...
# DP521E16I-A11  [{'path': 'DP/52/1E/16/IA/11/DP521E16I-A11@9.j...
# TA111X07D-Q11  [{'path': 'TA/11/1X/07/DQ/11/TA111X07D-Q11@3.j...
# PU121A03A-A11  [{'path': 'PU/12/1A/03/AA/11/PU121A03A-A11@9.j...
# L0U21I03F-B11  [{'path': 'L0/U2/1I/03/FB/11/L0U21I03F-B11@4.j...
# V1021I0TS-G11  [{'path': 'V1/02/1I/0T/SG/11/V1021I0TS-G11@8.j...
# M3211CA0M-Q11  [{'path': 'M3/21/1C/A0/MQ/11/M3211CA0M-Q11@13....
# NI111A0CQ-A12  [{'path': 'NI/11/1A/0C/QA/12/NI111A0CQ-A12@7.j...
# ON321E1G4-K11  [{'path': 'ON/32/1E/1G/4K/11/ON321E1G4-K11@9.j...
# ON321E1DH-A11  [{'path': 'ON/32/1E/1D/HA/11/ON321E1DH-A11@10....
# ON321U09B-C12  [{'path': 'ON/32/1U/09/BC/12/ON321U09B-C12@7.p...
# LE221J00U-A11  [{'path': 'LE/22/1J/00/UA/11/LE221J00U-A11@12....
# NM321I0B4-C11  [{'path': 'NM/32/1I/0B/4C/11/NM321I0B4-C11@4.j...
# VE121C1PX-Q11  [{'path': 'VE/12/1C/1P/XQ/11/VE121C1PX-Q11@21....
# AN621A03T-Q11  [{'path': 'AN/62/1A/03/TQ/11/AN621A03T-Q11@8.j...
# ON321I1F4-Q11  [{'path': 'ON/32/1I/1F/4Q/11/ON321I1F4-Q11@14....
# M0Q21N04T-C11  [{'path': 'M0/Q2/1N/04/TC/11/M0Q21N04T-C11@27....
# NL021E0U8-M11  [{'path': 'NL/02/1E/0U/8M/11/NL021E0U8-M11@8.j...
# NI121A08J-I11  [{'path': 'NI/12/1A/08/JI/11/NI121A08J-I11@4.j...
# SU221D1IN-C11  [{'path': 'SU/22/1D/1I/NC/11/SU221D1IN-C11@4.1...
#
#                                                             name  \
# sku
# CO411A0RW-Q11  CHUCK TAYLOR ALL STAR LIFT CLEAN - Baskets bas...
# HA111D00E-J15                         SLIM - Tongs - ballet rose
# HA111Z00Q-C11                       FREEDOM - Tongs - steel/grey
# NI111A0E6-C11  AIR MAX DIA SE - Baskets basses - white/laser ...
# NI121A05J-C11  PANT TIGHT - Pantalon de survêtement - charcoa...
# PU111A09B-K11       BOW BLOCK - Baskets basses - plat blue/black
# NI111A0EU-K11  AIR MAX 98 - Baskets basses - summit white/blu...
# OY121T00M-A11                                Combinaison - white
# PO221D04T-G11                              T-shirt imprimé - red
# PU111S05F-Q13  VIKKY PLATFORM - Baskets basses - black/white/...
# VA211S03A-Q11  OLD SKOOL PLATFORM - Baskets basses - black/white
# AD121A096-C11              TIGHT - Legging - medium grey heather
# CO411S099-A11  CHUCK TAYLOR ALL STAR BALLET LACE - Baskets ba...
# NI111A0D2-B11  M2K TEKNO - Baskets basses - desert ore/deep r...
# PU111A0EB-C11  VIKKY RIBBON WOMEN'S TRAINERS  - Baskets basse...
# HA111A00O-F11                       YOU MAXI - Tongs - rose gold
# HA111A00I-J11                 SLIM GLITTER - Tongs - ballet rose
# HA111B00K-F11             SLIM LOGO METALLIC - Tongs - rose gold
# LE221D033-A13              THE PERFECT - T-shirt imprimé - white
# LA221D03E-K11                        T-shirt basique - navy blue
# VE121G0QB-M11         VMKELL UTILITY  - Veste légère - ivy green
# 1FI11A01K-A11         DISRUPTOR PATCHES - Baskets basses - white
# LA211A09O-A11                LEROND CAW - Baskets basses - white
# NI121A08A-G11                  Legging - team red/university red
# NI121G03Q-E11   TRACK - Veste de survêtement - opti yellow/white
# NM321B055-K11  NMSONJA SHORT SKIRT - Jupe crayon - dark blue ...
# NI121D0E2-A11        DRY - T-shirt imprimé - white/midnight navy
# VE121C1G7-K11  VMKATINKA SHORT DRESS - Robe d'été - navy blaz...
# LA211S03Z-A11                   CARNABY - Baskets basses - white
# EV421E04A-I11                                  Chemisier - berry
# ...                                                          ...
# ED121S03W-K11                                PLAY - Short - navy
# NL011B0CW-G11   SERENITY - Escarpins à talons hauts - bright red
# RAD11A05C-E11            GRIER - Sandales à talons hauts - green
# NI121D0DS-A11  T-shirt à manches longues - white/black/desert...
# NI121D0DG-O11               T-shirt imprimé - desert ochre/black
# NL011N0A6-E11                 THRIVING - Boots à talons - yellow
# 1FI21D009-K12  ALLISON TEE - T-shirt imprimé - black iris/tru...
# PU111A0DP-A11                             Baskets basses - white
# PE321I067-C11                 PCDELLY - Pullover - whitecap gray
# TOB21D04S-Q11    SOFT V NECK TEE - T-shirt basique - tommy black
# C1781I00Y-A11  INTENSE POWER CLASSIC STRIPE - Bas de bikini -...
# DP521E16I-A11       SQUARE NECK TIE SLEEVE  - Blouse - off white
# TA111X07D-Q11                            Bottes de neige - black
# PU121A03A-A11            PANTS - Pantalon de survêtement - white
# L0U21I03F-B11     FRONT CUT OUT BARDOT JUMPER - Pullover - beige
# V1021I0TS-G11         VISOLDANA LAYER - Pullover - cherry tomato
# M3211CA0M-Q11                             Boots à talons - black
# NI111A0CQ-A12  AIR MAX 270 - Baskets basses - sail/pumice/spa...
# ON321E1G4-K11               ONLSEVANNA TANK - Blouse - night sky
# ON321E1DH-A11  ONLJULITS L/S JAQUARD DOTS DNM SHIR - Chemisie...
# ON321U09B-C12       ONLSEDONA  - Manteau court - oatmeal/melange
# LE221J00U-A11      GRAPHIC SPORT - Sweat à capuche - marshmallow
# NM321I0B4-C11  NMPATRICE HIGH NECK - Pullover - dark grey mel...
# VE121C1PX-Q11            VMSASHA BALI DRESS - Robe d'été - black
# AN621A03T-Q11                         Pantalon classique - black
# ON321I1F4-Q11                         ONLMAGA - Pullover - black
# M0Q21N04T-C11              VICE STONEWASH - Jeans Skinny - stone
# NL021E0U8-M11            CROSS BACK CAMI - Débardeur - mid green
# NI121A08J-I11  AIR PANT - Pantalon de survêtement - night mar...
# SU221D1IN-C11        ORANGE LABEL  - T-shirt basique - wolf grey
#
#                                                          outfits  \
# sku
# CO411A0RW-Q11                                                NaN
# HA111D00E-J15                                                NaN
# HA111Z00Q-C11                                                NaN
# NI111A0E6-C11                                                NaN
# NI121A05J-C11                                                NaN
# PU111A09B-K11                                                NaN
# NI111A0EU-K11                                                NaN
# OY121T00M-A11                                                NaN
# PO221D04T-G11                                                NaN
# PU111S05F-Q13                                                NaN
# VA211S03A-Q11                                                NaN
# AD121A096-C11                                                NaN
# CO411S099-A11                                                NaN
# NI111A0D2-B11                                                NaN
# PU111A0EB-C11                                                NaN
# HA111A00O-F11                                                NaN
# HA111A00I-J11                                                NaN
# HA111B00K-F11                                                NaN
# LE221D033-A13                                                NaN
# LA221D03E-K11                                                NaN
# VE121G0QB-M11                                                NaN
# 1FI11A01K-A11                                                NaN
# LA211A09O-A11                                                NaN
# NI121A08A-G11                                                NaN
# NI121G03Q-E11                                                NaN
# NM321B055-K11                                                NaN
# NI121D0E2-A11                                                NaN
# VE121C1G7-K11                                                NaN
# LA211S03Z-A11  [{'id': 'U3CkVHr0TWW', 'url_key': '/outfits/U3...
# EV421E04A-I11                                                NaN
# ...                                                          ...
# ED121S03W-K11                                                NaN
# NL011B0CW-G11                                                NaN
# RAD11A05C-E11                                                NaN
# NI121D0DS-A11                                                NaN
# NI121D0DG-O11                                                NaN
# NL011N0A6-E11                                                NaN
# 1FI21D009-K12                                                NaN
# PU111A0DP-A11                                                NaN
# PE321I067-C11                                                NaN
# TOB21D04S-Q11                                                NaN
# C1781I00Y-A11                                                NaN
# DP521E16I-A11                                                NaN
# TA111X07D-Q11                                                NaN
# PU121A03A-A11                                                NaN
# L0U21I03F-B11                                                NaN
# V1021I0TS-G11                                                NaN
# M3211CA0M-Q11                                                NaN
# NI111A0CQ-A12                                                NaN
# ON321E1G4-K11                                                NaN
# ON321E1DH-A11                                                NaN
# ON321U09B-C12                                                NaN
# LE221J00U-A11                                                NaN
# NM321I0B4-C11                                                NaN
# VE121C1PX-Q11                                                NaN
# AN621A03T-Q11                                                NaN
# ON321I1F4-Q11                                                NaN
# M0Q21N04T-C11                                                NaN
# NL021E0U8-M11                                                NaN
# NI121A08J-I11                                                NaN
# SU221D1IN-C11                                                NaN
#
#                price.has_different_original_prices  \
# sku
# CO411A0RW-Q11                                False
# HA111D00E-J15                                False
# HA111Z00Q-C11                                False
# NI111A0E6-C11                                False
# NI121A05J-C11                                False
# PU111A09B-K11                                False
# NI111A0EU-K11                                False
# OY121T00M-A11                                False
# PO221D04T-G11                                False
# PU111S05F-Q13                                False
# VA211S03A-Q11                                False
# AD121A096-C11                                False
# CO411S099-A11                                False
# NI111A0D2-B11                                False
# PU111A0EB-C11                                False
# HA111A00O-F11                                False
# HA111A00I-J11                                False
# HA111B00K-F11                                False
# LE221D033-A13                                False
# LA221D03E-K11                                False
# VE121G0QB-M11                                False
# 1FI11A01K-A11                                False
# LA211A09O-A11                                False
# NI121A08A-G11                                False
# NI121G03Q-E11                                False
# NM321B055-K11                                False
# NI121D0E2-A11                                False
# VE121C1G7-K11                                False
# LA211S03Z-A11                                False
# EV421E04A-I11                                False
# ...                                            ...
# ED121S03W-K11                                False
# NL011B0CW-G11                                False
# RAD11A05C-E11                                False
# NI121D0DS-A11                                False
# NI121D0DG-O11                                False
# NL011N0A6-E11                                False
# 1FI21D009-K12                                False
# PU111A0DP-A11                                False
# PE321I067-C11                                False
# TOB21D04S-Q11                                False
# C1781I00Y-A11                                False
# DP521E16I-A11                                False
# TA111X07D-Q11                                False
# PU121A03A-A11                                False
# L0U21I03F-B11                                False
# V1021I0TS-G11                                False
# M3211CA0M-Q11                                False
# NI111A0CQ-A12                                False
# ON321E1G4-K11                                False
# ON321E1DH-A11                                False
# ON321U09B-C12                                False
# LE221J00U-A11                                False
# NM321I0B4-C11                                False
# VE121C1PX-Q11                                False
# AN621A03T-Q11                                False
# ON321I1F4-Q11                                False
# M0Q21N04T-C11                                False
# NL021E0U8-M11                                False
# NI121A08J-I11                                False
# SU221D1IN-C11                                False
#
#                price.has_different_prices  \
# sku
# CO411A0RW-Q11                       False
# HA111D00E-J15                       False
# HA111Z00Q-C11                        True
# NI111A0E6-C11                        True
# NI121A05J-C11                       False
# PU111A09B-K11                       False
# NI111A0EU-K11                       False
# OY121T00M-A11                       False
# PO221D04T-G11                       False
# PU111S05F-Q13                       False
# VA211S03A-Q11                       False
# AD121A096-C11                        True
# CO411S099-A11                       False
# NI111A0D2-B11                       False
# PU111A0EB-C11                       False
# HA111A00O-F11                       False
# HA111A00I-J11                       False
# HA111B00K-F11                       False
# LE221D033-A13                       False
# LA221D03E-K11                       False
# VE121G0QB-M11                        True
# 1FI11A01K-A11                       False
# LA211A09O-A11                       False
# NI121A08A-G11                        True
# NI121G03Q-E11                        True
# NM321B055-K11                        True
# NI121D0E2-A11                        True
# VE121C1G7-K11                       False
# LA211S03Z-A11                       False
# EV421E04A-I11                       False
# ...                                   ...
# ED121S03W-K11                        True
# NL011B0CW-G11                       False
# RAD11A05C-E11                       False
# NI121D0DS-A11                        True
# NI121D0DG-O11                        True
# NL011N0A6-E11                       False
# 1FI21D009-K12                       False
# PU111A0DP-A11                       False
# PE321I067-C11                        True
# TOB21D04S-Q11                       False
# C1781I00Y-A11                       False
# DP521E16I-A11                       False
# TA111X07D-Q11                       False
# PU121A03A-A11                       False
# L0U21I03F-B11                       False
# V1021I0TS-G11                       False
# M3211CA0M-Q11                       False
# NI111A0CQ-A12                        True
# ON321E1G4-K11                       False
# ON321E1DH-A11                       False
# ON321U09B-C12                        True
# LE221J00U-A11                       False
# NM321I0B4-C11                       False
# VE121C1PX-Q11                       False
# AN621A03T-Q11                       False
# ON321I1F4-Q11                       False
# M0Q21N04T-C11                       False
# NL021E0U8-M11                       False
# NI121A08J-I11                       False
# SU221D1IN-C11                        True
#
#                price.has_different_promotional_prices  \
# sku
# CO411A0RW-Q11                                   False
# HA111D00E-J15                                   False
# HA111Z00Q-C11                                    True
# NI111A0E6-C11                                    True
# NI121A05J-C11                                   False
# PU111A09B-K11                                   False
# NI111A0EU-K11                                   False
# OY121T00M-A11                                   False
# PO221D04T-G11                                   False
# PU111S05F-Q13                                   False
# VA211S03A-Q11                                   False
# AD121A096-C11                                    True
# CO411S099-A11                                   False
# NI111A0D2-B11                                   False
# PU111A0EB-C11                                   False
# HA111A00O-F11                                   False
# HA111A00I-J11                                   False
# HA111B00K-F11                                   False
# LE221D033-A13                                   False
# LA221D03E-K11                                   False
# VE121G0QB-M11                                    True
# 1FI11A01K-A11                                   False
# LA211A09O-A11                                   False
# NI121A08A-G11                                    True
# NI121G03Q-E11                                    True
# NM321B055-K11                                    True
# NI121D0E2-A11                                    True
# VE121C1G7-K11                                   False
# LA211S03Z-A11                                   False
# EV421E04A-I11                                   False
# ...                                               ...
# ED121S03W-K11                                    True
# NL011B0CW-G11                                   False
# RAD11A05C-E11                                   False
# NI121D0DS-A11                                    True
# NI121D0DG-O11                                    True
# NL011N0A6-E11                                   False
# 1FI21D009-K12                                   False
# PU111A0DP-A11                                   False
# PE321I067-C11                                    True
# TOB21D04S-Q11                                   False
# C1781I00Y-A11                                   False
# DP521E16I-A11                                   False
# TA111X07D-Q11                                   False
# PU121A03A-A11                                   False
# L0U21I03F-B11                                   False
# V1021I0TS-G11                                   False
# M3211CA0M-Q11                                   False
# NI111A0CQ-A12                                    True
# ON321E1G4-K11                                   False
# ON321E1DH-A11                                   False
# ON321U09B-C12                                    True
# LE221J00U-A11                                   False
# NM321I0B4-C11                                   False
# VE121C1PX-Q11                                   False
# AN621A03T-Q11                                   False
# ON321I1F4-Q11                                   False
# M0Q21N04T-C11                                   False
# NL021E0U8-M11                                   False
# NI121A08J-I11                                   False
# SU221D1IN-C11                                    True
#
#                price.has_discount_on_selected_sizes_only price.original  \
# sku
# CO411A0RW-Q11                                      False        89,95 €
# HA111D00E-J15                                      False        25,95 €
# HA111Z00Q-C11                                      False        25,95 €
# NI111A0E6-C11                                      False       129,95 €
# NI121A05J-C11                                      False        34,95 €
# PU111A09B-K11                                      False       100,00 €
# NI111A0EU-K11                                      False       179,95 €
# OY121T00M-A11                                      False        25,99 €
# PO221D04T-G11                                      False        69,95 €
# PU111S05F-Q13                                      False        65,00 €
# VA211S03A-Q11                                      False        84,95 €
# AD121A096-C11                                      False        29,95 €
# CO411S099-A11                                      False        49,95 €
# NI111A0D2-B11                                      False        99,95 €
# PU111A0EB-C11                                      False        60,00 €
# HA111A00O-F11                                      False        33,95 €
# HA111A00I-J11                                      False        29,95 €
# HA111B00K-F11                                      False        29,95 €
# LE221D033-A13                                      False        24,95 €
# LA221D03E-K11                                      False        49,95 €
# VE121G0QB-M11                                      False        44,99 €
# 1FI11A01K-A11                                      False       129,95 €
# LA211A09O-A11                                      False        84,95 €
# NI121A08A-G11                                      False        39,95 €
# NI121G03Q-E11                                      False        59,95 €
# NM321B055-K11                                      False        29,99 €
# NI121D0E2-A11                                      False        54,95 €
# VE121C1G7-K11                                      False        27,99 €
# LA211S03Z-A11                                      False        94,95 €
# EV421E04A-I11                                      False        22,95 €
# ...                                                  ...            ...
# ED121S03W-K11                                      False        39,99 €
# NL011B0CW-G11                                      False        25,99 €
# RAD11A05C-E11                                      False        34,95 €
# NI121D0DS-A11                                      False        39,95 €
# NI121D0DG-O11                                      False        34,95 €
# NL011N0A6-E11                                      False        25,99 €
# 1FI21D009-K12                                      False        34,95 €
# PU111A0DP-A11                                      False        90,00 €
# PE321I067-C11                                      False        39,99 €
# TOB21D04S-Q11                                      False        29,95 €
# C1781I00Y-A11                                      False        43,95 €
# DP521E16I-A11                                      False        35,95 €
# TA111X07D-Q11                                      False        99,95 €
# PU121A03A-A11                                      False        59,95 €
# L0U21I03F-B11                                      False        32,99 €
# V1021I0TS-G11                                      False        29,99 €
# M3211CA0M-Q11                                      False        69,99 €
# NI111A0CQ-A12                                      False       149,95 €
# ON321E1G4-K11                                      False        24,95 €
# ON321E1DH-A11                                      False        29,99 €
# ON321U09B-C12                                      False        59,99 €
# LE221J00U-A11                                      False        69,95 €
# NM321I0B4-C11                                      False        34,99 €
# VE121C1PX-Q11                                      False        26,99 €
# AN621A03T-Q11                                      False        34,99 €
# ON321I1F4-Q11                                      False        26,99 €
# M0Q21N04T-C11                                      False        27,99 €
# NL021E0U8-M11                                      False        16,95 €
# NI121A08J-I11                                      False        54,95 €
# SU221D1IN-C11                                      False        24,95 €
#
#               price.promotional product_group  \
# sku
# CO411A0RW-Q11           81,00 €          shoe
# HA111D00E-J15           18,16 €          shoe
# HA111Z00Q-C11           18,16 €          shoe
# NI111A0E6-C11           44,95 €          shoe
# NI121A05J-C11           21,00 €      clothing
# PU111A09B-K11           19,00 €          shoe
# NI111A0EU-K11           89,95 €          shoe
# OY121T00M-A11           15,99 €      clothing
# PO221D04T-G11           21,00 €      clothing
# PU111S05F-Q13           25,00 €          shoe
# VA211S03A-Q11           76,45 €          shoe
# AD121A096-C11           18,00 €      clothing
# CO411S099-A11           34,95 €          shoe
# NI111A0D2-B11           64,95 €          shoe
# PU111A0EB-C11           25,00 €          shoe
# HA111A00O-F11           20,37 €          shoe
# HA111A00I-J11           21,00 €          shoe
# HA111B00K-F11           21,00 €          shoe
# LE221D033-A13           17,46 €      clothing
# LA221D03E-K11           35,00 €      clothing
# VE121G0QB-M11           13,50 €      clothing
# 1FI11A01K-A11           65,00 €          shoe
# LA211A09O-A11           50,95 €          shoe
# NI121A08A-G11           12,00 €      clothing
# NI121G03Q-E11           24,00 €      clothing
# NM321B055-K11            9,00 €      clothing
# NI121D0E2-A11           16,45 €      clothing
# VE121C1G7-K11           19,60 €      clothing
# LA211S03Z-A11           56,95 €          shoe
# EV421E04A-I11            6,90 €      clothing
# ...                         ...           ...
# ED121S03W-K11           16,00 €      clothing
# NL011B0CW-G11           13,00 €          shoe
# RAD11A05C-E11           10,50 €          shoe
# NI121D0DS-A11           20,00 €      clothing
# NI121D0DG-O11           21,00 €      clothing
# NL011N0A6-E11            7,80 €          shoe
# 1FI21D009-K12           29,71 €      clothing
# PU111A0DP-A11           63,00 €          shoe
# PE321I067-C11           12,00 €      clothing
# TOB21D04S-Q11           21,00 €      clothing
# C1781I00Y-A11           32,95 €    beach_wear
# DP521E16I-A11           10,79 €      clothing
# TA111X07D-Q11           29,95 €          shoe
# PU121A03A-A11           30,00 €      clothing
# L0U21I03F-B11           13,20 €      clothing
# V1021I0TS-G11            9,00 €      clothing
# M3211CA0M-Q11           28,00 €          shoe
# NI111A0CQ-A12          105,00 €          shoe
# ON321E1G4-K11            7,49 €      clothing
# ON321E1DH-A11            9,00 €      clothing
# ON321U09B-C12           17,95 €      clothing
# LE221J00U-A11           49,00 €      clothing
# NM321I0B4-C11           10,50 €      clothing
# VE121C1PX-Q11           21,60 €      clothing
# AN621A03T-Q11           28,00 €      clothing
# ON321I1F4-Q11            8,00 €      clothing
# M0Q21N04T-C11           16,80 €      clothing
# NL021E0U8-M11            7,65 €      clothing
# NI121A08J-I11           38,46 €      clothing
# SU221D1IN-C11            7,50 €      clothing
#
#                                                            sizes  \
# sku
# CO411A0RW-Q11  [36, 36.5, 37, 37.5, 38, 39, 39.5, 40, 41, 41....
# HA111D00E-J15                       [35/36, 37/38, 39/40, 41/42]
# HA111Z00Q-C11                       [35/36, 37/38, 39/40, 41/42]
# NI111A0E6-C11  [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5,...
# NI121A05J-C11                                  [XS, S, M, L, XL]
# PU111A09B-K11  [35.5, 36, 37, 37.5, 38, 38.5, 39, 40, 40.5, 4...
# NI111A0EU-K11  [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5,...
# OY121T00M-A11                                      [XS, S, M, L]
# PO221D04T-G11                                      [XS, S, M, L]
# PU111S05F-Q13     [36, 37, 37.5, 38, 38.5, 39, 40, 40.5, 41, 42]
# VA211S03A-Q11  [36, 36.5, 37, 38, 38.5, 39, 40, 40.5, 41, 42,...
# AD121A096-C11               [32, 34, 36, 38, 40, 42, 44, 46, 48]
# CO411S099-A11   [36, 37, 37.5, 38, 38.5, 39, 40, 40.5, 41, 42.5]
# NI111A0D2-B11  [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5,...
# PU111A0EB-C11             [35.5, 36, 37, 37.5, 38, 38.5, 39, 40]
# HA111A00O-F11                              [37/38, 39/40, 41/42]
# HA111A00I-J11                       [35/36, 37/38, 39/40, 41/42]
# HA111B00K-F11                              [35/36, 39/40, 41/42]
# LE221D033-A13                             [XXS, XS, S, M, L, XL]
# LA221D03E-K11                       [34, 36, 38, 40, 42, 44, 46]
# VE121G0QB-M11                                  [XS, S, M, L, XL]
# 1FI11A01K-A11                               [37, 38, 39, 41, 42]
# LA211A09O-A11  [35.5, 36, 37, 37.5, 38, 39, 39.5, 40, 40.5, 4...
# NI121A08A-G11                                  [XS, S, M, L, XL]
# NI121G03Q-E11                                      [S, M, L, XL]
# NM321B055-K11                                   [36, 38, 40, 42]
# NI121D0E2-A11                                  [XS, S, M, L, XL]
# VE121C1G7-K11                                  [XS, S, M, L, XL]
# LA211S03Z-A11  [35.5, 36, 37, 37.5, 38, 39, 39.5, 40, 40.5, 4...
# EV421E04A-I11                               [36, 38, 40, 42, 46]
# ...                                                          ...
# ED121S03W-K11                       [34, 36, 38, 40, 42, 44, 46]
# NL011B0CW-G11                               [38, 39, 40, 41, 42]
# RAD11A05C-E11                               [36, 37, 38, 39, 41]
# NI121D0DS-A11                             [XS, S, M, L, XL, XXL]
# NI121D0DG-O11                                      [XS, S, M, L]
# NL011N0A6-E11                       [36, 37, 38, 39, 40, 41, 42]
# 1FI21D009-K12                                  [XS, S, M, L, XL]
# PU111A0DP-A11     [36, 37, 37.5, 38, 38.5, 39, 40, 40.5, 41, 42]
# PE321I067-C11                                  [XS, S, M, L, XL]
# TOB21D04S-Q11                             [XXS, XS, S, M, L, XL]
# C1781I00Y-A11                                         [XS, S, M]
# DP521E16I-A11                               [34, 40, 42, 44, 46]
# TA111X07D-Q11                               [37, 38, 39, 40, 41]
# PU121A03A-A11                                      [S, M, L, XL]
# L0U21I03F-B11                               [34, 36, 38, 40, 42]
# V1021I0TS-G11                                  [XS, S, M, L, XL]
# M3211CA0M-Q11                               [36, 37, 38, 40, 42]
# NI111A0CQ-A12  [36, 36.5, 37.5, 38, 38.5, 39, 40, 41, 42, 42....
# ON321E1G4-K11                               [36, 38, 40, 42, 44]
# ON321E1DH-A11                               [36, 38, 40, 42, 44]
# ON321U09B-C12                                      [XS, S, M, L]
# LE221J00U-A11                                 [XXS, XS, S, M, L]
# NM321I0B4-C11                               [36, 38, 40, 42, 44]
# VE121C1PX-Q11                                  [XS, S, M, L, XL]
# AN621A03T-Q11                       [34, 36, 38, 40, 42, 44, 46]
# ON321I1F4-Q11                                      [S, M, L, XL]
# M0Q21N04T-C11                               [34, 36, 38, 40, 42]
# NL021E0U8-M11                       [34, 36, 38, 40, 42, 44, 46]
# NI121A08J-I11                                  [XS, S, M, L, XL]
# SU221D1IN-C11                                 [XXS, XS, S, M, L]
#
#                           tracking_information.impression_beacon  \
# sku
# CO411A0RW-Q11  https://ccp-et.metrigo.zalan.do/event/sbv?z=5f...
# HA111D00E-J15  https://ccp-et.metrigo.zalan.do/event/sbv?z=5f...
# HA111Z00Q-C11  https://ccp-et.metrigo.zalan.do/event/sbv?z=5f...
# NI111A0E6-C11                                                NaN
# NI121A05J-C11                                                NaN
# PU111A09B-K11                                                NaN
# NI111A0EU-K11                                                NaN
# OY121T00M-A11                                                NaN
# PO221D04T-G11                                                NaN
# PU111S05F-Q13                                                NaN
# VA211S03A-Q11                                                NaN
# AD121A096-C11                                                NaN
# CO411S099-A11                                                NaN
# NI111A0D2-B11                                                NaN
# PU111A0EB-C11                                                NaN
# HA111A00O-F11  https://ccp-et.metrigo.zalan.do/event/sbv?z=5f...
# HA111A00I-J11  https://ccp-et.metrigo.zalan.do/event/sbv?z=5f...
# HA111B00K-F11  https://ccp-et.metrigo.zalan.do/event/sbv?z=5f...
# LE221D033-A13                                                NaN
# LA221D03E-K11                                                NaN
# VE121G0QB-M11                                                NaN
# 1FI11A01K-A11                                                NaN
# LA211A09O-A11                                                NaN
# NI121A08A-G11                                                NaN
# NI121G03Q-E11                                                NaN
# NM321B055-K11                                                NaN
# NI121D0E2-A11                                                NaN
# VE121C1G7-K11                                                NaN
# LA211S03Z-A11                                                NaN
# EV421E04A-I11                                                NaN
# ...                                                          ...
# ED121S03W-K11                                                NaN
# NL011B0CW-G11                                                NaN
# RAD11A05C-E11                                                NaN
# NI121D0DS-A11                                                NaN
# NI121D0DG-O11                                                NaN
# NL011N0A6-E11                                                NaN
# 1FI21D009-K12                                                NaN
# PU111A0DP-A11                                                NaN
# PE321I067-C11                                                NaN
# TOB21D04S-Q11                                                NaN
# C1781I00Y-A11                                                NaN
# DP521E16I-A11                                                NaN
# TA111X07D-Q11                                                NaN
# PU121A03A-A11                                                NaN
# L0U21I03F-B11                                                NaN
# V1021I0TS-G11                                                NaN
# M3211CA0M-Q11                                                NaN
# NI111A0CQ-A12                                                NaN
# ON321E1G4-K11                                                NaN
# ON321E1DH-A11                                                NaN
# ON321U09B-C12                                                NaN
# LE221J00U-A11                                                NaN
# NM321I0B4-C11                                                NaN
# VE121C1PX-Q11                                                NaN
# AN621A03T-Q11                                                NaN
# ON321I1F4-Q11                                                NaN
# M0Q21N04T-C11                                                NaN
# NL021E0U8-M11                                                NaN
# NI121A08J-I11                                                NaN
# SU221D1IN-C11                                                NaN
#
#                     tracking_information.metrigo_impression_urls  \
# sku
# CO411A0RW-Q11  [https://ccp-et.metrigo.zalan.do/event/sbv?z=5...
# HA111D00E-J15  [https://ccp-et.metrigo.zalan.do/event/sbv?z=5...
# HA111Z00Q-C11  [https://ccp-et.metrigo.zalan.do/event/sbv?z=5...
# NI111A0E6-C11                                                NaN
# NI121A05J-C11                                                NaN
# PU111A09B-K11                                                NaN
# NI111A0EU-K11                                                NaN
# OY121T00M-A11                                                NaN
# PO221D04T-G11                                                NaN
# PU111S05F-Q13                                                NaN
# VA211S03A-Q11                                                NaN
# AD121A096-C11                                                NaN
# CO411S099-A11                                                NaN
# NI111A0D2-B11                                                NaN
# PU111A0EB-C11                                                NaN
# HA111A00O-F11  [https://ccp-et.metrigo.zalan.do/event/sbv?z=5...
# HA111A00I-J11  [https://ccp-et.metrigo.zalan.do/event/sbv?z=5...
# HA111B00K-F11  [https://ccp-et.metrigo.zalan.do/event/sbv?z=5...
# LE221D033-A13                                                NaN
# LA221D03E-K11                                                NaN
# VE121G0QB-M11                                                NaN
# 1FI11A01K-A11                                                NaN
# LA211A09O-A11                                                NaN
# NI121A08A-G11                                                NaN
# NI121G03Q-E11                                                NaN
# NM321B055-K11                                                NaN
# NI121D0E2-A11                                                NaN
# VE121C1G7-K11                                                NaN
# LA211S03Z-A11                                                NaN
# EV421E04A-I11                                                NaN
# ...                                                          ...
# ED121S03W-K11                                                NaN
# NL011B0CW-G11                                                NaN
# RAD11A05C-E11                                                NaN
# NI121D0DS-A11                                                NaN
# NI121D0DG-O11                                                NaN
# NL011N0A6-E11                                                NaN
# 1FI21D009-K12                                                NaN
# PU111A0DP-A11                                                NaN
# PE321I067-C11                                                NaN
# TOB21D04S-Q11                                                NaN
# C1781I00Y-A11                                                NaN
# DP521E16I-A11                                                NaN
# TA111X07D-Q11                                                NaN
# PU121A03A-A11                                                NaN
# L0U21I03F-B11                                                NaN
# V1021I0TS-G11                                                NaN
# M3211CA0M-Q11                                                NaN
# NI111A0CQ-A12                                                NaN
# ON321E1G4-K11                                                NaN
# ON321E1DH-A11                                                NaN
# ON321U09B-C12                                                NaN
# LE221J00U-A11                                                NaN
# NM321I0B4-C11                                                NaN
# VE121C1PX-Q11                                                NaN
# AN621A03T-Q11                                                NaN
# ON321I1F4-Q11                                                NaN
# M0Q21N04T-C11                                                NaN
# NL021E0U8-M11                                                NaN
# NI121A08J-I11                                                NaN
# SU221D1IN-C11                                                NaN
#
#               tracking_information.source  \
# sku
# CO411A0RW-Q11                         ccp
# HA111D00E-J15                         ccp
# HA111Z00Q-C11                         ccp
# NI111A0E6-C11                         NaN
# NI121A05J-C11                         NaN
# PU111A09B-K11                         NaN
# NI111A0EU-K11                         NaN
# OY121T00M-A11                         NaN
# PO221D04T-G11                         NaN
# PU111S05F-Q13                         NaN
# VA211S03A-Q11                         NaN
# AD121A096-C11                         NaN
# CO411S099-A11                         NaN
# NI111A0D2-B11                         NaN
# PU111A0EB-C11                         NaN
# HA111A00O-F11                         ccp
# HA111A00I-J11                         ccp
# HA111B00K-F11                         ccp
# LE221D033-A13                         NaN
# LA221D03E-K11                         NaN
# VE121G0QB-M11                         NaN
# 1FI11A01K-A11                         NaN
# LA211A09O-A11                         NaN
# NI121A08A-G11                         NaN
# NI121G03Q-E11                         NaN
# NM321B055-K11                         NaN
# NI121D0E2-A11                         NaN
# VE121C1G7-K11                         NaN
# LA211S03Z-A11                         NaN
# EV421E04A-I11                         NaN
# ...                                   ...
# ED121S03W-K11                         NaN
# NL011B0CW-G11                         NaN
# RAD11A05C-E11                         NaN
# NI121D0DS-A11                         NaN
# NI121D0DG-O11                         NaN
# NL011N0A6-E11                         NaN
# 1FI21D009-K12                         NaN
# PU111A0DP-A11                         NaN
# PE321I067-C11                         NaN
# TOB21D04S-Q11                         NaN
# C1781I00Y-A11                         NaN
# DP521E16I-A11                         NaN
# TA111X07D-Q11                         NaN
# PU121A03A-A11                         NaN
# L0U21I03F-B11                         NaN
# V1021I0TS-G11                         NaN
# M3211CA0M-Q11                         NaN
# NI111A0CQ-A12                         NaN
# ON321E1G4-K11                         NaN
# ON321E1DH-A11                         NaN
# ON321U09B-C12                         NaN
# LE221J00U-A11                         NaN
# NM321I0B4-C11                         NaN
# VE121C1PX-Q11                         NaN
# AN621A03T-Q11                         NaN
# ON321I1F4-Q11                         NaN
# M0Q21N04T-C11                         NaN
# NL021E0U8-M11                         NaN
# NI121A08J-I11                         NaN
# SU221D1IN-C11                         NaN
#
#                                                          url_key
# sku
# CO411A0RW-Q11  converse-chuck-taylor-all-star-lift-clean-bask...
# HA111D00E-J15                 havaianas-slim-tongs-ha111d00e-j15
# HA111Z00Q-C11              havaianas-freedom-tongs-ha111z00q-c11
# NI111A0E6-C11  nike-sportswear-air-max-dia-se-baskets-basses-...
# NI121A05J-C11  nike-sportswear-pant-tight-pantalon-de-survete...
# PU111A09B-K11        puma-bow-block-baskets-basses-pu111a09b-k11
# NI111A0EU-K11  nike-sportswear-air-max-98-baskets-basses-ni11...
# OY121T00M-A11              oysho-combinaison-white-oy121t00m-a11
# PO221D04T-G11  polo-ralph-lauren-t-shirt-imprime-red-po221d04...
# PU111S05F-Q13   puma-vikky-platform-baskets-basses-pu111s05f-q13
# VA211S03A-Q11       vans-baskets-basses-blackwhite-va211s03a-q11
# AD121A096-C11  adidas-originals-3-stripes-tight-leggings-medi...
# CO411S099-A11        converse-baskets-basses-blanc-co411s099-a11
# NI111A0D2-B11  nike-sportswear-m2k-tekno-baskets-basses-ni111...
# PU111A0EB-C11  puma-vikky-ribbon-womens-trainers-baskets-bass...
# HA111A00O-F11             havaianas-you-maxi-tongs-ha111a00o-f11
# HA111A00I-J11         havaianas-slim-glitter-tongs-ha111a00i-j11
# HA111B00K-F11   havaianas-slim-logo-metallic-tongs-ha111b00k-f11
# LE221D033-A13   levi-s-the-perfect-t-shirt-imprime-le221d033-a13
# LA221D03E-K11    lacoste-t-shirt-basique-navy-blue-la221d03e-k11
# VE121G0QB-M11  vero-moda-vmkell-utility-veste-legere-ivy-gree...
# 1FI11A01K-A11  fila-disruptor-patches-baskets-basses-white-1f...
# LA211A09O-A11  lacoste-lerond-caw-baskets-basses-white-la211a...
# NI121A08A-G11  nike-sportswear-legging-team-reduniversity-red...
# NI121G03Q-E11  nike-sportswear-track-veste-de-survetement-opt...
# NM321B055-K11  noisy-may-nmsonja-short-skirt-minijupe-dark-bl...
# NI121D0E2-A11  nike-sportswear-dry-t-shirt-imprime-whitemidni...
# VE121C1G7-K11  vero-moda-vmkatinka-short-dress-robe-dete-ve12...
# LA211S03Z-A11  lacoste-carnaby-baskets-basses-white-la211s03z...
# EV421E04A-I11           evenandodd-chemisier-berry-ev421e04a-i11
# ...                                                          ...
# ED121S03W-K11             edc-by-esprit-play-short-ed121s03w-k11
# NL011B0CW-G11  new-look-serenity-escarpins-bright-red-nl011b0...
# RAD11A05C-E11            raid-grier-sandales-green-rad11a05c-e11
# NI121D0DS-A11  nike-sportswear-t-shirt-a-manches-longues-whit...
# NI121D0DG-O11  nike-sportswear-t-shirt-imprime-desert-ochrebl...
# NL011N0A6-E11  new-look-thriving-boots-a-talons-yellow-nl011n...
# 1FI21D009-K12     fila-allison-tee-t-shirt-imprime-1fi21d009-k12
# PU111A0DP-A11            puma-baskets-basses-white-pu111a0dp-a11
# PE321I067-C11        pieces-pullover-whitecap-gray-pe321i067-c11
# TOB21D04S-Q11  tommy-jeans-soft-v-neck-tee-t-shirt-imprime-to...
# C1781I00Y-A11  calvin-klein-swimwear-intense-power-classic-st...
# DP521E16I-A11  dorothy-perkins-square-neck-tie-sleeve-blouse-...
# TA111X07D-Q11        tamaris-bottes-de-neige-black-ta111x07d-q11
# PU121A03A-A11   puma-pants-pantalon-de-survetement-pu121a03a-a11
# L0U21I03F-B11  lost-ink-front-cut-out-bardot-jumper-pullover-...
# V1021I0TS-G11  vila-visoldana-layer-pullover-cherry-tomato-v1...
# M3211CA0M-Q11    mintandberry-boots-a-talons-black-m3211ca0m-q11
# NI111A0CQ-A12  nike-sportswear-air-max-270-baskets-basses-ni1...
# ON321E1G4-K11       only-onlsevanna-tank-debardeur-on321e1g4-k11
# ON321E1DH-A11  only-onljulits-ls-jaquard-dots-dnm-shir-chemis...
# ON321U09B-C12  only-onlsedona-link-spring-coat-manteau-classi...
# LE221J00U-A11      levisr-graphic-sport-sweatshirt-le221j00u-a11
# NM321I0B4-C11  noisy-may-nmpatrice-high-neck-pullover-nm321i0...
# VE121C1PX-Q11  vero-moda-vmsasha-bali-short-dress-robe-dete-b...
# AN621A03T-Q11  anna-field-pantalon-classique-black-an621a03t-q11
# ON321I1F4-Q11          only-onlmaga-pullover-black-on321i1f4-q11
# M0Q21N04T-C11  missguided-vice-stonewash-jeans-skinny-stone-m...
# NL021E0U8-M11   new-look-cross-back-cami-debardeur-nl021e0u8-m11
# NI121A08J-I11  nike-sportswear-air-pant-pantalon-de-surveteme...
# SU221D1IN-C11  superdry-t-shirt-basique-wolf-grey-marl-su221d...
#
# [168 rows x 19 columns]

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# The trending brand.

df.brand_name.value_counts().index[0]
# Out:
# 'Nike Sportswear'

# %%
# The product(s) with the highest discount.

df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

total_disc=df1.groupby(['brand_name']).sum().discount_amount

total_disc.sort_values(ascending=False).index[0]
# Out:
# brand_name
# Nike Sportswear             658.45
# Polo Ralph Lauren           464.75
# adidas Originals            366.50
# Puma                        267.90
# Fila                        189.19
# ONLY                        188.38
# Pier One                    161.93
# mint&berry                  145.20
# Levi's®                     139.25
# New Look                    131.19
# Lacoste                     126.95
# Vero Moda                   123.23
# Even&Odd                     90.90
# New Balance                  84.95
# Carhartt WIP                 83.90
# RAID                         83.48
# Reebok Classic               80.41
# Hollister Co.                74.05
# Vila                         73.47
# Tamaris                      70.00
# Glamorous                    69.58
# Public Desire                67.23
# Anna Field                   57.38
# TWINTIP                      55.53
# kate spade new york          52.50
# Converse                     49.95
# Havaianas                    47.06
# Noisy May                    45.48
# Missguided Petite            38.50
# Dr.Denim                     35.95
# Vans                         33.99
# Noisy May Tall               29.39
# Gina Tricot                  27.99
# Pieces                       27.99
# Glamorous Petite             25.99
# JDY                          25.44
# Dorothy Perkins              25.16
# edc by Esprit                23.99
# Calvin Klein Swimwear        21.18
# Missguided                   21.17
# Espadrij l´originale         20.95
# Lost Ink                     19.79
# Superdry                     17.45
# PULL&BEAR                    16.80
# Esprit                       15.99
# Nike Performance             14.95
# PARFOIS                      13.95
# OYSHO                        10.00
# Tommy Jeans                   8.95
# River Island                  5.95
# Dorothy Perkins Wide Fit      5.19
# Name: discount_amount, dtype: float64

# %%
total_disc[total_disc.sort_values(ascending=False).index[0]]
# Out:
# 658.45

# %%
# The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

df['original_price']=df['price.original'].astype(float)
df2=df.copy()


sum_discounted_prices=df2.sum().discount_amount
sum_original_prices=df2.sum().original_price
sum_of_discounts=sum_discounted_prices / sum_original_prices


print(sum_of_discounts)
# Out:
# 0.49309150051804235
